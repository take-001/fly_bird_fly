# %%
import gymnasium
import flappy_bird_gymnasium
import pickle
import gc
import numpy as np
import pygame
import itertools
import random
import torch
import torch.nn as nn
import torch.optim as optim
from collections import deque
from enum import IntEnum
from torchvision.transforms import Compose, ToTensor, Resize, Grayscale
from flappy_bird_gymnasium.envs.flappy_bird_env import FlappyBirdEnv
from flappy_bird_gymnasium.envs.flappy_bird_env import Actions
from flappy_bird_gymnasium.envs.lidar import LIDAR
from flappy_bird_gymnasium.envs.constants import (
    PLAYER_FLAP_ACC,
    PLAYER_ACC_Y,
    PLAYER_MAX_VEL_Y,
    PLAYER_HEIGHT,
    PLAYER_VEL_ROT,
    PLAYER_WIDTH,
    PIPE_WIDTH,
    PIPE_VEL_X,
)

import matplotlib.pyplot as plt
import numpy as np
import matplotlib.cm as cm
from matplotlib.font_manager import FontProperties



def new_render(self):
    """Renders the next frame."""
    if self.render_mode == "rgb_array":
        self._draw_surface(show_score=False, show_rays=False)
        # Flip the image to retrieve a correct aspect
        return np.transpose(pygame.surfarray.array3d(self._surface), axes=(1, 0, 2))
    else:
        self._draw_surface(show_score=True, show_rays=False)
        if self._display is None:
            self._make_display()

        self._update_display()
        self._fps_clock.tick(self.metadata["render_fps"])


FlappyBirdEnv.render = new_render

# %%
###############
######DQN######
###############

class DQN(nn.Module):
    def __init__(self, input_dim, action_space):
        super(DQN, self).__init__()
        self.fc1 = nn.Linear(input_dim, 128)  # First hidden layer
        self.fc2 = nn.Linear(128, 128)   
        self.fc3 = nn.Linear(128, 128)      # Second hidden layer
        self.fc4 = nn.Linear(128, action_space)  # Output layer for Q-values

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = torch.relu(self.fc3(x))
        return self.fc4(x)



# Replay Memory to store experiences
class ReplayMemory:
    def __init__(self, capacity):
        self.memory = deque(maxlen=capacity)

    def push(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

    def __len__(self):
        return len(self.memory)


# DQN Agent Class
class DQNAgent:
    def __init__(self, 
                 env,
                 hyper ={
                          "learning_rate": 0.001,
                          "discount_factor" : 0.99,
                          "epsilon" : 1.0,
                          "epsilon_decay" :0.999,
                          "epsilon_min" : 0.01,
                          "batch_size" : 64,
                          "memory_size" : 10000,
                          "episodes" : 100000,
                          "target_update_freq" : 10
                        }
                 ):
        # Environment
        self.env = env
        self.state_dim = env.observation_space.shape[0]  # First dimension of observation
        self.action_space = env.action_space.n


        # Hyperparameters
        self.learning_rate = hyper["learning_rate"]
        self.discount_factor = hyper["discount_factor"]
        self.epsilon = hyper["epsilon"]
        self.epsilon_decay = hyper["epsilon_decay"]
        self.epsilon_min = hyper["epsilon_min"]
        self.batch_size = hyper["batch_size"]
        self.memory_size = hyper["memory_size"]
        self.episodes = hyper["episodes"]
        self.target_update_freq = hyper["target_update_freq"]

        # Initialize policy and target networks
        self.policy_net = DQN(self.state_dim, self.action_space)
        self.target_net = DQN(self.state_dim, self.action_space)
        self.target_net.load_state_dict(self.policy_net.state_dict())
        self.target_net.eval()

        # Optimizer and Replay Memory
        self.optimizer = optim.Adam(self.policy_net.parameters(), lr=self.learning_rate)
        self.memory = ReplayMemory(self.memory_size)

    def select_action(self, state, testing=False):
        """Epsilon-greedy action selection."""
        if not testing and random.random() < self.epsilon:
            return random.randint(0, self.action_space - 1)  # Random action
        else:
            with torch.no_grad():
                state = torch.tensor(state, dtype=torch.float32).unsqueeze(0)
                return self.policy_net(state).argmax(dim=1).item()

    def optimize_model(self):
        """Sample a batch from memory and optimize the policy network."""
        if len(self.memory) < self.batch_size:
            return

        batch = self.memory.sample(self.batch_size)
        states, actions, rewards, next_states, dones = zip(*batch)

        # Convert to tensors and move to device
        states = torch.tensor(states, dtype=torch.float32).to(self.device)
        actions = torch.tensor(actions, dtype=torch.long).unsqueeze(1).to(self.device)
        rewards = torch.tensor(rewards, dtype=torch.float32).unsqueeze(1).to(self.device)
        next_states = torch.tensor(next_states, dtype=torch.float32).to(self.device)
        dones = torch.tensor(dones, dtype=torch.float32).unsqueeze(1).to(self.device)

        # Compute Q-values and targets
        q_values = self.policy_net(states).gather(1, actions)
        next_q_values = self.target_net(next_states).max(1, keepdim=True)[0]
        targets = rewards + (self.discount_factor * next_q_values * (1 - dones))

        # Loss and backpropagation
        loss = nn.MSELoss()(q_values, targets)
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

    def train(self):
        res=[]
        """Train the agent."""
        for episode in range(self.episodes):
            state, _ = self.env.reset()
            done = False
            total_reward = 0

            while not done:
                # Select and execute action
                action = self.select_action(state)
                next_state, reward, done, _, _ = self.env.step(action)
                self.memory.push(state, action, reward, next_state, done)
                state = next_state
                total_reward += reward

                # Optimize model
                self.optimize_model()

            # Update target network periodically
            if episode % self.target_update_freq == 0:
                self.target_net.load_state_dict(self.policy_net.state_dict())

            # Decay epsilon
            self.epsilon = max(self.epsilon_min, self.epsilon * self.epsilon_decay)

            res.append(total_reward)
            print(f"Episode: {episode + 1}, Total Reward: {total_reward}, Epsilon: {self.epsilon:.4f}")

        self.env.close()
        print("Training complete!")

        return res

    def test(self, num_episodes=10,render="human"):
        """Test the trained policy with real-time rendering."""
        print("\nTesting the trained policy...\n")
        self.epsilon = 0.0  # Disable exploration
        test_env = gymnasium.make("FlappyBird-v0", render_mode=render,use_lidar=True)  # Render in "human" mode 
        total_rewards = []

        for episode in range(num_episodes):
            state, _ = test_env.reset()
            done = False
            total_reward = 0

            while not done:
                action = self.select_action(state, testing=True)
                next_state, reward, done, _, _ = test_env.step(action)
                state = next_state
                total_reward += reward

            total_rewards.append(total_reward)
            print(f"Test Episode: {episode + 1}, Total Reward: {total_reward}")

        avg_reward = np.mean(total_rewards)
        print(f"\nAverage Reward over {num_episodes} Test Episodes: {avg_reward}")
        test_env.close()
        return total_rewards

# %%
#############################
######AC policygradient######
#############################


class ActorCriticNet(nn.Module):
    def __init__(self, input_dim, action_space):
        super(ActorCriticNet, self).__init__()
        # Shared layers
        self.fc1 = nn.Linear(input_dim, 128)
        self.fc2 = nn.Linear(128, 128)
        
        # Actor head
        self.actor = nn.Linear(128, action_space)
        
        # Critic head
        self.critic = nn.Linear(128, 1)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        policy_logits = torch.softmax(self.actor(x), dim=-1)  # Action probabilities
        value = self.critic(x)  # State value
        return policy_logits, value
    
class ActorCriticAgent:
    def __init__(self, env):
        # Environment
        self.env = env
        self.state_dim = env.observation_space.shape[0]  # First dimension of observation
        self.action_space = env.action_space.n

        # Hyperparameters
        self.learning_rate = 0.001
        self.discount_factor = 0.99
        self.episodes = 5000

        # Initialize actor-critic network
        self.actor_critic_net = ActorCriticNet(self.state_dim, self.action_space)
        self.optimizer = optim.Adam(self.actor_critic_net.parameters(), lr=self.learning_rate)

        # Memory for rewards, values, and log probabilities
        self.log_probs = []
        self.rewards = []
        self.values = []

    def select_action(self, state):
        """Select an action based on the policy."""
        state = torch.tensor(state, dtype=torch.float32).unsqueeze(0)
        policy_logits, value = self.actor_critic_net(state)
        action_dist = torch.distributions.Categorical(policy_logits)
        action = action_dist.sample()
        
        # Store log probability and value
        self.log_probs.append(action_dist.log_prob(action))
        self.values.append(value)
        return action.item()

    def compute_returns(self):
        """Compute discounted returns for each time step."""
        returns = []
        G = 0
        for reward in reversed(self.rewards):
            G = reward + self.discount_factor * G
            returns.insert(0, G)
        returns = torch.tensor(returns, dtype=torch.float32)
        return returns

    def train_step(self):
        """Perform a training step after one episode."""
        returns = self.compute_returns()
        values = torch.cat(self.values).squeeze()
        log_probs = torch.cat(self.log_probs)
        
        # Compute advantage
        advantage = returns - values.detach()  # Detach critic from the actor's gradient computation
        
        # Actor loss (policy gradient with advantage)
        actor_loss = -(log_probs * advantage).mean()

        # Critic loss (value estimation error)
        critic_loss = torch.nn.functional.mse_loss(values, returns)

        # Total loss
        loss = actor_loss + critic_loss

        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

        # Clear memory
        self.log_probs = []
        self.rewards = []
        self.values = []

    def train(self):
        res = []
        """Train the agent."""
        for episode in range(self.episodes):
            state, _ = self.env.reset()
            done = False
            total_reward = 0

            while not done:
                action = self.select_action(state)
                next_state, reward, done, _, _ = self.env.step(action)
                
                self.rewards.append(reward)
                state = next_state
                total_reward += reward

            # Perform a training step after the episode ends
            self.train_step()

            res.append(total_reward)
            print(f"Episode: {episode + 1}, Total Reward: {total_reward}")

        self.env.close()
        print("Training complete!")
        return res

    def test(self, num_episodes=10, render="human"):
        """Test the trained policy with real-time rendering."""
        print("\nTesting the trained policy...\n")
        test_env = gymnasium.make("FlappyBird-v0", render_mode=render, use_lidar=True)
        total_rewards = []

        for episode in range(num_episodes):
            state, _ = test_env.reset()
            done = False
            total_reward = 0

            while not done:
                state = torch.tensor(state, dtype=torch.float32).unsqueeze(0)
                policy_logits, _ = self.actor_critic_net(state)
                action = torch.argmax(policy_logits).item()  # Select action with highest probability
                next_state, reward, done, _, _ = test_env.step(action)
                state = next_state
                total_reward += reward

            total_rewards.append(total_reward)
            print(f"Test Episode: {episode + 1}, Total Reward: {total_reward}")

        avg_reward = np.mean(total_rewards)
        print(f"\nAverage Reward over {num_episodes} Test Episodes: {avg_reward}")
        test_env.close()

        return total_rewards

# %%
#############################
######Policygradient#########
#############################

class PolicyGradientNet(nn.Module):
    def __init__(self, input_dim, action_space):
        super(PolicyGradientNet, self).__init__()
        self.fc1 = nn.Linear(input_dim, 128)  # First hidden layer
        self.fc2 = nn.Linear(128, 128)       # Second hidden layer
        self.fc3 = nn.Linear(128, action_space)  # Output layer for action probabilities

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        return torch.softmax(self.fc3(x), dim=-1)  # Apply softmax to output layer for probabilities


# Policy Gradient Agent Class
class PolicyGradientAgent:
    def __init__(self, env):
        # Environment
        self.env = env
        self.state_dim = env.observation_space.shape[0]  # First dimension of observation
        self.action_space = env.action_space.n

        # Hyperparameters
        self.learning_rate = 0.001
        self.discount_factor = 0.99
        self.episodes = 2000

        # Initialize policy network
        self.policy_net = PolicyGradientNet(self.state_dim, self.action_space)
        self.optimizer = optim.Adam(self.policy_net.parameters(), lr=self.learning_rate)

        # Memory for rewards and log probabilities
        self.log_probs = []
        self.rewards = []

    def select_action(self, state):
        """Select an action based on policy."""
        state = torch.tensor(state, dtype=torch.float32).unsqueeze(0)
        probs = self.policy_net(state)
        action_dist = torch.distributions.Categorical(probs)
        action = action_dist.sample()
        self.log_probs.append(action_dist.log_prob(action))
        return action.item()

    def compute_returns(self):
        """Compute discounted returns for each time step."""
        returns = []
        G = 0
        for reward in reversed(self.rewards):
            G = reward + self.discount_factor * G
            returns.insert(0, G)
        returns = torch.tensor(returns, dtype=torch.float32)
        # Normalize returns for better convergence
        returns = (returns - returns.mean()) / (returns.std() + 1e-8)
        return returns

    def train_step(self):
        """Perform a training step after one episode."""
        returns = self.compute_returns()
        loss = 0
        for log_prob, G in zip(self.log_probs, returns):
            loss += -log_prob * G  # Negative sign for gradient ascent

        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

        # Clear memory
        self.log_probs = []
        self.rewards = []

    def train(self):
        res=[]
        """Train the agent."""
        for episode in range(self.episodes):
            state, _ = self.env.reset()
            done = False
            total_reward = 0

            while not done:
                action = self.select_action(state)
                next_state, reward, done, _, _ = self.env.step(action)
                self.rewards.append(reward)
                state = next_state
                total_reward += reward

            # Perform a training step after the episode ends
            self.train_step()

            res.append(total_reward)
            print(f"Episode: {episode + 1}, Total Reward: {total_reward}")

        self.env.close()
        print("Training complete!")
        return res

    def test(self, num_episodes=10,render="human"):
        """Test the trained policy with real-time rendering."""
        print("\nTesting the trained policy...\n")
        test_env = gymnasium.make("FlappyBird-v0", render_mode=render, use_lidar=True)
        total_rewards = []

        for episode in range(num_episodes):
            state, _ = test_env.reset()
            done = False
            total_reward = 0

            while not done:
                state = torch.tensor(state, dtype=torch.float32).unsqueeze(0)
                probs = self.policy_net(state)
                action = torch.argmax(probs).item()  # Select action with highest probability
                next_state, reward, done, _, _ = test_env.step(action)
                state = next_state
                total_reward += reward

            total_rewards.append(total_reward)
            print(f"Test Episode: {episode + 1}, Total Reward: {total_reward}")

        avg_reward = np.mean(total_rewards)
        print(f"\nAverage Reward over {num_episodes} Test Episodes: {avg_reward}")
        test_env.close()

# %%
#####################
######DQNCNN#########
#####################

class DQNCNN(nn.Module):
    def __init__(self, input_dim, action_space):
        super(DQNCNN, self).__init__()
        self.conv1 = nn.Conv2d(input_dim[0], 32, kernel_size=8, stride=4)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=4, stride=2)
        self.conv3 = nn.Conv2d(64, 64, kernel_size=3, stride=1)
        self.fc1 = nn.Linear(self._calculate_conv_output(input_dim), 512)
        self.fc2 = nn.Linear(512, action_space)

    def _calculate_conv_output(self, input_dim):
        dummy_input = torch.zeros(1, *input_dim)
        x = self.conv1(dummy_input)
        x = self.conv2(x)
        x = self.conv3(x)
        return int(torch.prod(torch.tensor(x.shape[1:])))
    
    def forward(self, x):
        x = x.view(x.size(0), -1, x.size(-2), x.size(-1))
        x = torch.relu(self.conv1(x))
        x = torch.relu(self.conv2(x))
        x = torch.relu(self.conv3(x))
        x = x.view(x.size(0), -1)  # Flatten the tensor
        x = torch.relu(self.fc1(x))
        return self.fc2(x)
    

class ReplayMemory:
    def __init__(self, capacity):
        self.memory = deque(maxlen=capacity)

    def push(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

    def __len__(self):
        return len(self.memory)


class DQCNNAgent:
    def __init__(self, env, input_dim, action_space):
        self.env = env
        self.input_dim = input_dim
        self.action_space = action_space

        # Hyperparameters
        self.learning_rate = 0.0001
        self.discount_factor = 0.99
        self.epsilon = 1.0
        self.epsilon_decay = 0.995
        self.epsilon_min = 0.1
        self.batch_size = 64
        self.memory_size = 10000
        self.target_update_freq = 10

        # Networks
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.policy_net = DQNCNN(input_dim, action_space).to(self.device)
        self.target_net = DQNCNN(input_dim, action_space).to(self.device)
        self.target_net.load_state_dict(self.policy_net.state_dict())
        self.target_net.eval()

        self.optimizer = optim.Adam(self.policy_net.parameters(), lr=self.learning_rate)
        self.memory = ReplayMemory(self.memory_size)

        # Preprocessing pipeline
        self.preprocess = Compose([ToTensor(), Resize((84, 84)), Grayscale()])

    def preprocess_frame(self, frame):
        return self.preprocess(frame).numpy()

    def select_action(self, state, testing=False):
        if not testing and np.random.rand() < self.epsilon:
            return random.randint(0, self.action_space - 1)
        else:
            state = torch.FloatTensor(state).unsqueeze(0).to(self.device)
            with torch.no_grad():
                return self.policy_net(state).argmax(dim=1).item()

    def optimize_model(self):
        if len(self.memory) < self.batch_size:
            return

        batch = self.memory.sample(self.batch_size)
        states, actions, rewards, next_states, dones = zip(*batch)

        states = torch.FloatTensor(states).to(self.device)
        actions = torch.LongTensor(actions).unsqueeze(1).to(self.device)
        rewards = torch.FloatTensor(rewards).unsqueeze(1).to(self.device)
        next_states = torch.FloatTensor(next_states).to(self.device)
        dones = torch.FloatTensor(dones).unsqueeze(1).to(self.device)

        # Q-value computation
        q_values = self.policy_net(states).gather(1, actions)
        with torch.no_grad():
            next_q_values = self.target_net(next_states).max(1, keepdim=True)[0]
            target_q_values = rewards + (1 - dones) * self.discount_factor * next_q_values

        loss = nn.MSELoss()(q_values, target_q_values)
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

    def train(self, episodes=1000):
        results = []
        for episode in range(episodes):
            state, _ = self.env.reset()
            frame = self.env.render()  # Query the initial rendered frame
            state = self.preprocess_frame(frame)
            state_stack = np.stack([state] * 4, axis=0)
            total_reward = 0
            done = False

            while not done:
                action = self.select_action(state_stack)
                next_state, reward, done, truncated, _ = self.env.step(action)
                next_frame = self.env.render()  # Query the next rendered frame
                next_state = self.preprocess_frame(next_frame)
                next_state_stack = np.append(state_stack[1:], [next_state], axis=0)

                self.memory.push(state_stack, action, reward, next_state_stack, done)
                self.optimize_model()
                state_stack = next_state_stack
                total_reward += reward

                if truncated:
                    done = True

            if episode % self.target_update_freq == 0:
                self.target_net.load_state_dict(self.policy_net.state_dict())

            self.epsilon = max(self.epsilon_min, self.epsilon * self.epsilon_decay)
            results.append(total_reward)
            print(f"Episode {episode + 1}, Total Reward: {total_reward}, Epsilon: {self.epsilon:.4f}")
        return results


    def test(self, num_episodes=10):
        self.epsilon = 0.0  # Test with deterministic policy
        total_rewards = []

        for episode in range(num_episodes):
            state, _ = self.env.reset()
            frame = self.env.render()  # Query the rendered frame
            state = self.preprocess_frame(frame)
            state_stack = np.stack([state] * 4, axis=0)
            total_reward = 0
            done = False

            while not done:
                action = self.select_action(state_stack, testing=True)
                next_state, reward, done, truncated, _ = self.env.step(action)
                next_frame = self.env.render()  # Query the rendered frame
                state_stack = np.append(state_stack[1:], [self.preprocess_frame(next_frame)], axis=0)
                total_reward += reward

                if truncated:
                    done = True

            total_rewards.append(total_reward)
            print(f"Test Episode {episode + 1}, Total Reward: {total_reward}")

        avg_reward = np.mean(total_rewards)
        print(f"\nAverage Reward over {num_episodes} Test Episodes: {avg_reward}")

# %%
################
######DQN+######
################

class DQN_plus(nn.Module):
    def __init__(self, input_dim, action_space):
        super(DQN_plus, self).__init__()
        self.fc1 = nn.Linear(input_dim, 128)  # First hidden layer
        self.fc2 = nn.Linear(128, 128)   
        self.fc3 = nn.Linear(128, 128)      # Second hidden layer
        self.fc4 = nn.Linear(128, action_space)  # Output layer for Q-values

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = torch.relu(self.fc3(x))
        return self.fc4(x)



class DQN_plus_Agent:
    def __init__(self, 
                 env,
                 hyper ={
                          "learning_rate": 0.001,
                          "discount_factor" : 0.99,
                          "epsilon" : 1.0,
                          "epsilon_decay" :0.999,
                          "epsilon_min" : 0.01,
                          "batch_size" : 64,
                          "memory_size" : 10000,
                          "episodes" : 100000,
                          "target_update_freq" : 10,
                          "rho" :1.0,
                          "kappa" : 1.0,
                          "eps_update_freq":100
                        }
                 ):
        # Environment
        self.env = env
        self.state_dim = env.observation_space.shape[0]
        self.action_space = env.action_space.n

        # Device setup for GPU
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        print(self.device)

        # Hyperparameters
        self.learning_rate = hyper["learning_rate"]
        self.discount_factor = hyper["discount_factor"]
        self.epsilon = hyper["epsilon"]
        self.epsilon_decay = hyper["epsilon_decay"]
        self.epsilon_min = hyper["epsilon_min"]
        self.batch_size = hyper["batch_size"]
        self.memory_size = hyper["memory_size"]
        self.episodes = hyper["episodes"]
        self.target_update_freq = hyper["target_update_freq"]
        self.rho = hyper["rho"]
        self.kappa = hyper["kappa"]
        self.eps_update_freq=hyper["eps_update_freq"]

        # Initialize policy and target networks
        self.policy_net = DQN_plus(self.state_dim, self.action_space).to(self.device)
        self.target_net = DQN_plus(self.state_dim, self.action_space).to(self.device)
        self.target_net.load_state_dict(self.policy_net.state_dict())
        self.target_net.eval()

        # Optimizer and Replay Memory
        self.optimizer = optim.Adam(self.policy_net.parameters(), lr=self.learning_rate)
        self.memory = ReplayMemory(self.memory_size)

    def select_action(self, state, testing=False):
        """Epsilon-greedy action selection."""
        if not testing and random.random() < self.epsilon:
            return random.randint(0, self.action_space - 1)  # Random action
        else:
            with torch.no_grad():
                state = torch.tensor(state, dtype=torch.float32).unsqueeze(0).to(self.device)
                return self.policy_net(state).argmax(dim=1).item()

    def optimize_model(self):
        """Sample a batch from memory and optimize the policy network."""
        if len(self.memory) < self.batch_size:
            return

        batch = self.memory.sample(self.batch_size)
        states, actions, rewards, next_states, dones = zip(*batch)

        # Convert to tensors and move to device
        states = torch.tensor(states, dtype=torch.float32).to(self.device)
        actions = torch.tensor(actions, dtype=torch.long).unsqueeze(1).to(self.device)
        rewards = torch.tensor(rewards, dtype=torch.float32).unsqueeze(1).to(self.device)
        next_states = torch.tensor(next_states, dtype=torch.float32).to(self.device)
        dones = torch.tensor(dones, dtype=torch.float32).unsqueeze(1).to(self.device)

        # Compute Q-values and targets
        q_values = self.policy_net(states).gather(1, actions)
        next_q_values = self.target_net(next_states).max(1, keepdim=True)[0]
        targets = rewards + (self.discount_factor * next_q_values * (1 - dones))

        # Loss and backpropagation
        loss = nn.MSELoss()(q_values, targets)
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()


    def train(self):
        res=[]
        reward_trace=0
        old_reward_trace=0
        """Train the agent."""
        for episode in range(self.episodes):
            state, _ = self.env.reset()
            done = False
            total_reward = 0

            while not done:
                # Select and execute action
                action = self.select_action(state)
                next_state, reward, done, _, _ = self.env.step(action)
                self.memory.push(state, action, reward, next_state, done)
                state = next_state
                total_reward += reward

                # Optimize model
                self.optimize_model()


            # Decay epsilon
            self.epsilon = max(self.epsilon_min, self.epsilon * self.epsilon_decay)

            
            # Update target network periodically
            reward_trace+=total_reward
            if episode % self.target_update_freq == 0:
                self.target_net.load_state_dict(self.policy_net.state_dict())

      
            if (reward_trace-old_reward_trace)/self.target_update_freq <self.kappa and abs(self.epsilon-self.epsilon_min) < 1e-4 and  episode % self.eps_update_freq== 0:
                self.epsilon = self.rho
                
                old_reward_trace=reward_trace
                reward_trace=0



            res.append(total_reward)
            print(f"Episode: {episode + 1}, Total Reward: {total_reward}, Epsilon: {self.epsilon:.4f}")

        self.env.close()
        print("Training complete!")

        return res

    def test(self, num_episodes=10,render="human"):
        
        """Test the trained policy with real-time rendering."""
        print("\nTesting the trained policy...\n")
        self.epsilon = 0.0  # Disable exploration
        test_env = gymnasium.make("FlappyBird-v0", render_mode=render,use_lidar=True)  # Render in "human" mode 
        total_rewards = []

        for episode in range(num_episodes):
            state, _ = test_env.reset()
            done = False
            total_reward = 0

            while not done:
                action = self.select_action(state, testing=True)
                next_state, reward, done, _, _ = test_env.step(action)
                state = next_state
                total_reward += reward

            total_rewards.append(total_reward)
        
            print(f"Test Episode: {episode + 1}, Total Reward: {total_reward}")

        
        avg_reward = np.mean(total_rewards)
        print(f"\nAverage Reward over {num_episodes} Test Episodes: {avg_reward}")
        test_env.close()

        return total_rewards

# %%
# Initialize environment
env = gymnasium.make("FlappyBird-v0", render_mode="rgb_array", use_lidar=True)

# Hyperparameters
hyper = {
    "learning_rate": [0.001, 0.005],
    "discount_factor": 0.99,
    "epsilon": 1.0,
    "epsilon_decay": [0.995, 0.999],
    "epsilon_min": 0.01,
    "batch_size": 64,
    "memory_size": 10000,
    "episodes": 20000,
    "target_update_freq": [10, 20]
}

param_combinations = itertools.product(
    hyper["learning_rate"], 
    hyper["epsilon_decay"], 
    hyper["target_update_freq"]
)

# Initialize result dictionaries
exp_res = {}
test_res = {}

# Iterate through parameter combinations
for lr, epsilon_decay, target_update_freq in param_combinations:
    current_hyperparams = {
        "learning_rate": lr,
        "discount_factor": hyper["discount_factor"],
        "epsilon": hyper["epsilon"],
        "epsilon_decay": epsilon_decay,
        "epsilon_min": hyper["epsilon_min"],
        "batch_size": hyper["batch_size"],
        "memory_size": hyper["memory_size"],
        "episodes": hyper["episodes"],
        "target_update_freq": target_update_freq
    }
    
    try:
        # Train the agent
        agent = DQNAgent(env, current_hyperparams)
        exp_key = f"lr={lr}_decay={epsilon_decay}_freq={target_update_freq}"
        exp_res[exp_key] = agent.train()
        
        # Test the agent
        test_res[exp_key] = agent.test(num_episodes=5000, render=None)
        
        # Save intermediate results
        with open("exp_res.pkl", "wb") as f:
            pickle.dump(exp_res, f)
        with open("test_res.pkl", "wb") as f:
            pickle.dump(test_res, f)
        
        print(f"Finished training and testing for: {exp_key}")
    
    finally:
        # Free resources
        del agent
        gc.collect()
        env.close()


with open("exp_res.pkl", "rb") as f:
    exp_res = pickle.load(f)
with open("test_res.pkl", "rb") as f:
    test_res = pickle.load(f)

print("All parameter combinations processed.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 43
#      29 current_hyperparams = {
#      30     "learning_rate": lr,
#      31     "discount_factor": hyper["discount_factor"],
#    (...)
#      38     "target_update_freq": target_update_freq
#      39 }
#      41 try:
#      42     # Train the agent
# ---> 43     agent = DQNAgent(env, current_hyperparams)
#      44     exp_key = f"lr={lr}_decay={epsilon_decay}_freq={target_update_freq}"
#      45     exp_res[exp_key] = agent.train()
#
# NameError: name 'DQNAgent' is not defined

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.cm as cm
from matplotlib.font_manager import FontProperties


def smooth_data(data, window_size=5):
    """Apply a simple moving average smoothing to the data."""
    return np.convolve(data, np.ones(window_size)/window_size, mode='valid')

def plot_rewards_with_opacity(rewards_dict, title, xlabel, ylabel, img_name):
    # Calculate coefficients of variation
    cv_rewards = {key: np.mean(rewards)/np.std(rewards) for key, rewards in rewards_dict.items()}  
    top3_keys = sorted(cv_rewards, key=cv_rewards.get, reverse=True)[:3]
    
    # Set up the figure and axis
    fig, ax = plt.subplots(figsize=(15, 6))
    num_combinations = len(rewards_dict)
    cmap = cm.get_cmap("cool", num_combinations)
    
    # Loop through each hyperparameter combination
    for idx, (key, rewards) in enumerate(rewards_dict.items()):
        # Smooth the rewards using moving average
        smoothed_rewards = smooth_data(rewards, window_size=10)
        
        # Choose a color for the line based on the index
        color = cmap(idx)
        
        # Adjust opacity for non-top3 combinations
        alpha = 1.0 if key in top3_keys else 0.15
        
        # Plot the smoothed data with a linewidth for visibility
        ax.plot(range(1, len(smoothed_rewards) + 1), smoothed_rewards, label=key, color=color, alpha=alpha, linewidth=1.2)
    
    # Set title with bold font
    ax.set_title(title, fontweight='bold', fontsize=18)
    ax.set_xlabel(xlabel, fontweight='bold')
    ax.set_ylabel(ylabel, fontweight='bold')
    
    # Create a FontProperties object for the legend title to make it bold
    font_props = FontProperties(weight='bold')
    
    # Place the legend outside the figure on the middle-right
    ax.legend(loc='center left', 
              bbox_to_anchor=(1.05, 0.5),  # Position the legend box outside to the right
              borderaxespad=0., 
              fancybox=True, 
              fontsize='small', 
              markerscale=0.5, 
            
              title_fontproperties=font_props)  # Make the title bold
    
    # Save the figure and show the plot
    fig.savefig(f'img/{img_name}.png', dpi=600) 
    plt.tight_layout()  # Ensures the legend does not get clipped
    plt.show()

# Plot for exp_res (training rewards)
plot_rewards_with_opacity(exp_res, "Training Rewards (Top3, Normalized Avg.)", "Episode", "Reward", "TR_rewards_cv.png")

# Plot for test_res (test rewards)
plot_rewards_with_opacity(test_res, "Test Rewards (Top3, Normalized Avg.)", "Episode", "Reward", "Ts_rewards_cv.png")
# Out:
# /tmp/ipykernel_169913/2865349045.py:19: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap("cool", num_combinations)

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.cm as cm

def smooth_data(data, window_size=5):
    """Apply a simple moving average smoothing to the data."""
    return np.convolve(data, np.ones(window_size)/window_size, mode='valid')

def plot_rewards_with_opacity(rewards_dict, title, xlabel, ylabel, img_name):

    avg_rewards = {key: np.mean(rewards) for key, rewards in rewards_dict.items()} ##coefficients of variation
    top3_keys = sorted(avg_rewards, key=avg_rewards.get, reverse=True)[:3]
    
    

    fig, ax = plt.subplots(figsize=(15, 6))
    num_combinations = len(rewards_dict)
    cmap = cm.get_cmap("cool", num_combinations)
    
    # Loop through each hyperparameter combination and plot with a color from the colormap
    for idx, (key, rewards) in enumerate(rewards_dict.items()):

        smoothed_rewards = smooth_data(rewards, window_size=10)
        color = cmap(idx)  # Get the color for this hyperparameter combination
        # Adjust opacity for non-top3 combinations
        alpha = 1.0 if key in top3_keys else 0.2
        ax.plot(range(1, len(smoothed_rewards) + 1), smoothed_rewards, label=key, color=color, alpha=alpha,linewidth=0.7)
    
    # Set title with bold font
    ax.set_title(title, fontweight='bold',fontsize=18)
    ax.set_xlabel(xlabel,fontweight='bold')
    ax.set_ylabel(ylabel,fontweight='bold')
    
    
    # Place the legend in the bottom-right corner, remove title, and make it smaller
    ax.legend(loc='center left', 
              bbox_to_anchor=(1.05, 0.5),  # Position the legend box outside to the right
              borderaxespad=0., 
              fancybox=True, 
              fontsize='small', 
              markerscale=0.5, 
            )  # Make the title bold
    fig.savefig(f'img/{img_name}.png',dpi=600) 
    plt.tight_layout()  # Ensures the legend does not get clipped
    plt.show()

# Plot for exp_res (training rewards)
plot_rewards_with_opacity(exp_res, "Training Rewards (Top3, Avg.)", "Episode", "Reward","TR_rewards_avg.png")

# Plot for test_res (test rewards)
plot_rewards_with_opacity(test_res, "Test Rewards (Top3, Avg.)", "Episode", "Reward","Ts_rewards_avg.png")
# Out:
# /tmp/ipykernel_169913/3705388015.py:18: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap("cool", num_combinations)

# %%
env = gymnasium.make("FlappyBird-v0", render_mode="rgb_array",use_lidar=True ) ##use_lidar=True option avaliable

agent = DQN_plus_Agent(env)
agent.train()
agent.test(num_episodes=10)
# Out:
# -7.499999999999998 0
# Episode: 1, Total Reward: -7.499999999999998, Epsilon: 0.9990
# Episode: 2, Total Reward: -6.899999999999999, Epsilon: 0.9980
# Episode: 3, Total Reward: -6.899999999999999, Epsilon: 0.9970
# Episode: 4, Total Reward: -6.299999999999999, Epsilon: 0.9960
# Episode: 5, Total Reward: -5.699999999999998, Epsilon: 0.9950
# Episode: 6, Total Reward: -8.7, Epsilon: 0.9940
# Episode: 7, Total Reward: -6.299999999999999, Epsilon: 0.9930
# Episode: 8, Total Reward: -5.099999999999998, Epsilon: 0.9920
# Episode: 9, Total Reward: -7.499999999999998, Epsilon: 0.9910
# Episode: 10, Total Reward: -6.299999999999999, Epsilon: 0.9900
# -65.39999999999999 -7.499999999999998
# Episode: 11, Total Reward: -5.699999999999998, Epsilon: 0.9990
# Episode: 12, Total Reward: -8.099999999999998, Epsilon: 0.9980
# Episode: 13, Total Reward: -8.099999999999998, Epsilon: 0.9970
# Episode: 14, Total Reward: -6.899999999999999, Epsilon: 0.9960
# Episode: 15, Total Reward: -7.499999999999998, Epsilon: 0.9950
# Episode: 16, Total Reward: -8.7, Epsilon: 0.9940
# Episode: 17, Total Reward: -8.099999999999998, Epsilon: 0.9930
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[108], line 4
#       1 env = gymnasium.make("FlappyBird-v0", render_mode="rgb_array",use_lidar=True ) ##use_lidar=True option avaliable
#       3 agent = DQN_plus_Agent(env)
# ----> 4 agent.train()
#       5 agent.test(num_episodes=10)
#
# Cell In[105], line 137, in DQN_plus_Agent.train(self)
#     134     total_reward += reward
#     136     # Optimize model
# --> 137     self.optimize_model()
#     139 # Update target network periodically
#     140 reward_trace+=total_reward
#
# Cell In[105], line 113, in DQN_plus_Agent.optimize_model(self)
#     110 targets = rewards + (self.discount_factor * next_q_values * (1 - dones))
#     112 # Loss and backpropagation
# --> 113 loss = nn.MSELoss()(q_values, targets)
#     114 self.optimizer.zero_grad()
#     115 loss.backward()
#
# File ~/anaconda3/envs/flappy/lib/python3.10/site-packages/torch/nn/modules/module.py:1732, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1729             tracing_state.pop_scope()
#    1730     return result
# -> 1732 def _wrapped_call_impl(self, *args, **kwargs):
#    1733     if self._compiled_call_impl is not None:
#    1734         return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#
# KeyboardInterrupt:

# %%
import gymnasium
import itertools
import pickle
import gc


# Initialize environment
env = gymnasium.make("FlappyBird-v0", render_mode="rgb_array", use_lidar=True)

# Hyperparameters
hyper = {
    "learning_rate": 0.001,
    "discount_factor": 0.99,
    "epsilon": 1.0,
    "epsilon_decay": 0.995,
    "epsilon_min": 0.01,
    "batch_size": 64,
    "memory_size": 10000,
    "episodes": 40000,
    "target_update_freq": 10,
    "rho":[0.1,0.2],
    "kappa":[0.25,0.5,0.75],
    "eps_update_freq":[10,100,1000]
}

param_combinations = itertools.product(
    hyper["rho"], 
    hyper["kappa"],
    hyper["eps_update_freq"]
)

# Initialize result dictionaries
exp_res_DQN_plus = {}
test_res_DQN_plus  = {}

# Iterate through parameter combinations
for rho, kappa,eps_update_freq in param_combinations:
    current_hyperparams = {
        "learning_rate": hyper["learning_rate"],
        "discount_factor": hyper["discount_factor"],
        "epsilon": hyper["epsilon"],
        "epsilon_decay": hyper["epsilon_decay"],
        "epsilon_min": hyper["epsilon_min"],
        "batch_size": hyper["batch_size"],
        "memory_size": hyper["memory_size"],
        "episodes": hyper["episodes"],
        "target_update_freq": hyper["target_update_freq"],
        "rho" :rho,
        "kappa" :kappa,
        "eps_update_freq" : eps_update_freq
    }
    
    try:
        # Train the agent
        agent = DQN_plus_Agent(env, current_hyperparams)
        exp_key = f"rho={rho}_kappa={kappa}"
        exp_res_DQN_plus[exp_key] = agent.train()
        
        # Test the agent
        test_res_DQN_plus[exp_key] = agent.test(num_episodes=5000, render=None)
        
        # Save intermediate results
        with open("exp_res_DQN_plus.pkl", "wb") as f:
            pickle.dump(exp_res_DQN_plus, f)
        with open("test_res_DQN_plus.pkl", "wb") as f:
            pickle.dump(test_res_DQN_plus, f)
        
        print(f"Finished training and testing for: {exp_key}")
    
    finally:
        # Free resources
        del agent
        gc.collect()
        env.close()


with open("exp_res_DQN_plus.pkl", "rb") as f:
    exp_res_DQN_plus = pickle.load(f)
with open("test_res_DQN_plus.pkl", "rb") as f:
    test_res_DQN_plus = pickle.load(f)

print("All parameter combinations processed.")
# Out:
# cuda
# Episode: 1, Total Reward: -8.099999999999998, Epsilon: 0.9950
# Episode: 2, Total Reward: -7.499999999999998, Epsilon: 0.9900
# Episode: 3, Total Reward: -6.899999999999999, Epsilon: 0.9851
# Episode: 4, Total Reward: -8.099999999999998, Epsilon: 0.9801
# Episode: 5, Total Reward: -7.499999999999998, Epsilon: 0.9752
# Episode: 6, Total Reward: -8.099999999999998, Epsilon: 0.9704
# Episode: 7, Total Reward: -8.099999999999998, Epsilon: 0.9655
# Episode: 8, Total Reward: -7.499999999999998, Epsilon: 0.9607
# Episode: 9, Total Reward: -7.499999999999998, Epsilon: 0.9559
# Episode: 10, Total Reward: -7.499999999999998, Epsilon: 0.9511
# Episode: 11, Total Reward: -5.699999999999998, Epsilon: 0.9464
# Episode: 12, Total Reward: -8.099999999999998, Epsilon: 0.9416
# Episode: 13, Total Reward: -8.099999999999998, Epsilon: 0.9369
# Episode: 14, Total Reward: -8.099999999999998, Epsilon: 0.9322
# Episode: 15, Total Reward: -8.099999999999998, Epsilon: 0.9276
# Episode: 16, Total Reward: -8.099999999999998, Epsilon: 0.9229
# Episode: 17, Total Reward: -8.7, Epsilon: 0.9183
# Episode: 18, Total Reward: -8.099999999999998, Epsilon: 0.9137
# Episode: 19, Total Reward: -5.699999999999998, Epsilon: 0.9092
# Episode: 20, Total Reward: -7.499999999999998, Epsilon: 0.9046
# Episode: 21, Total Reward: -6.899999999999999, Epsilon: 0.9001
# Episode: 22, Total Reward: -6.299999999999999, Epsilon: 0.8956
# Episode: 23, Total Reward: -7.499999999999998, Epsilon: 0.8911
# Episode: 24, Total Reward: -6.899999999999999, Epsilon: 0.8867
# Episode: 25, Total Reward: -6.899999999999999, Epsilon: 0.8822
# Episode: 26, Total Reward: -8.099999999999998, Epsilon: 0.8778
# Episode: 27, Total Reward: -5.699999999999998, Epsilon: 0.8734
# Episode: 28, Total Reward: -6.899999999999999, Epsilon: 0.8691
# Episode: 29, Total Reward: -8.7, Epsilon: 0.8647
# Episode: 30, Total Reward: -8.099999999999998, Epsilon: 0.8604
# Episode: 31, Total Reward: -8.099999999999998, Epsilon: 0.8561
# Episode: 32, Total Reward: -7.499999999999998, Epsilon: 0.8518
# Episode: 33, Total Reward: -6.299999999999999, Epsilon: 0.8475
# Episode: 34, Total Reward: -6.899999999999999, Epsilon: 0.8433
# Episode: 35, Total Reward: -6.299999999999999, Epsilon: 0.8391
# Episode: 36, Total Reward: -6.899999999999999, Epsilon: 0.8349
# Episode: 37, Total Reward: -8.099999999999998, Epsilon: 0.8307
# Episode: 38, Total Reward: -8.099999999999998, Epsilon: 0.8266
# Episode: 39, Total Reward: -8.099999999999998, Epsilon: 0.8224
# Episode: 40, Total Reward: -7.499999999999998, Epsilon: 0.8183
# Episode: 41, Total Reward: -8.099999999999998, Epsilon: 0.8142
# Episode: 42, Total Reward: -8.099999999999998, Epsilon: 0.8102
# Episode: 43, Total Reward: -8.099999999999998, Epsilon: 0.8061
# Episode: 44, Total Reward: -8.7, Epsilon: 0.8021
# Episode: 45, Total Reward: -7.499999999999998, Epsilon: 0.7981
# Episode: 46, Total Reward: -7.499999999999998, Epsilon: 0.7941
# Episode: 47, Total Reward: -6.899999999999999, Epsilon: 0.7901
# Episode: 48, Total Reward: -8.099999999999998, Epsilon: 0.7862
# Episode: 49, Total Reward: -8.099999999999998, Epsilon: 0.7822
# Episode: 50, Total Reward: -7.499999999999998, Epsilon: 0.7783
# Episode: 51, Total Reward: -7.499999999999998, Epsilon: 0.7744
# Episode: 52, Total Reward: -5.099999999999998, Epsilon: 0.7705
# Episode: 53, Total Reward: -7.499999999999998, Epsilon: 0.7667
# Episode: 54, Total Reward: -6.899999999999999, Epsilon: 0.7629
# Episode: 55, Total Reward: -8.7, Epsilon: 0.7590
# Episode: 56, Total Reward: -8.7, Epsilon: 0.7553
# Episode: 57, Total Reward: -8.099999999999998, Epsilon: 0.7515
# Episode: 58, Total Reward: -8.099999999999998, Epsilon: 0.7477
# Episode: 59, Total Reward: -7.499999999999998, Epsilon: 0.7440
# Episode: 60, Total Reward: -6.899999999999999, Epsilon: 0.7403
# Episode: 61, Total Reward: -8.7, Epsilon: 0.7366
# Episode: 62, Total Reward: -6.299999999999999, Epsilon: 0.7329
# Episode: 63, Total Reward: -7.499999999999998, Epsilon: 0.7292
# Episode: 64, Total Reward: -7.499999999999998, Epsilon: 0.7256
# Episode: 65, Total Reward: -8.099999999999998, Epsilon: 0.7219
# Episode: 66, Total Reward: -8.099999999999998, Epsilon: 0.7183
# Episode: 67, Total Reward: -8.7, Epsilon: 0.7147
# Episode: 68, Total Reward: -7.499999999999998, Epsilon: 0.7112
# Episode: 69, Total Reward: -7.499999999999998, Epsilon: 0.7076
# Episode: 70, Total Reward: -7.499999999999998, Epsilon: 0.7041
# Episode: 71, Total Reward: -6.899999999999999, Epsilon: 0.7005
# Episode: 72, Total Reward: -8.099999999999998, Epsilon: 0.6970
# Episode: 73, Total Reward: -6.899999999999999, Epsilon: 0.6936
# Episode: 74, Total Reward: -6.899999999999999, Epsilon: 0.6901
# Episode: 75, Total Reward: -8.7, Epsilon: 0.6866
# Episode: 76, Total Reward: -8.099999999999998, Epsilon: 0.6832
# Episode: 77, Total Reward: -7.499999999999998, Epsilon: 0.6798
# Episode: 78, Total Reward: -6.899999999999999, Epsilon: 0.6764
# Episode: 79, Total Reward: -7.499999999999998, Epsilon: 0.6730
# Episode: 80, Total Reward: -7.499999999999998, Epsilon: 0.6696
# Episode: 81, Total Reward: -8.7, Epsilon: 0.6663
# Episode: 82, Total Reward: -7.499999999999998, Epsilon: 0.6630
# Episode: 83, Total Reward: -6.899999999999999, Epsilon: 0.6597
# Episode: 84, Total Reward: -8.7, Epsilon: 0.6564
# Episode: 85, Total Reward: -8.099999999999998, Epsilon: 0.6531
# Episode: 86, Total Reward: -7.499999999999998, Epsilon: 0.6498
# Episode: 87, Total Reward: -5.699999999999998, Epsilon: 0.6466
# Episode: 88, Total Reward: -8.099999999999998, Epsilon: 0.6433
# Episode: 89, Total Reward: -7.499999999999998, Epsilon: 0.6401
# Episode: 90, Total Reward: -5.099999999999998, Epsilon: 0.6369
# Episode: 91, Total Reward: -8.099999999999998, Epsilon: 0.6337
# Episode: 92, Total Reward: -7.499999999999998, Epsilon: 0.6306
# Episode: 93, Total Reward: -8.7, Epsilon: 0.6274
# Episode: 94, Total Reward: -6.899999999999999, Epsilon: 0.6243
# Episode: 95, Total Reward: -5.099999999999998, Epsilon: 0.6211
# Episode: 96, Total Reward: -6.899999999999999, Epsilon: 0.6180
# Episode: 97, Total Reward: -7.499999999999998, Epsilon: 0.6149
# Episode: 98, Total Reward: -5.099999999999998, Epsilon: 0.6119
# Episode: 99, Total Reward: -5.699999999999998, Epsilon: 0.6088
# Episode: 100, Total Reward: -5.099999999999998, Epsilon: 0.6058
# Episode: 101, Total Reward: -6.299999999999999, Epsilon: 0.6027
# Episode: 102, Total Reward: -6.299999999999999, Epsilon: 0.5997
# Episode: 103, Total Reward: -8.099999999999998, Epsilon: 0.5967
# Episode: 104, Total Reward: -8.099999999999998, Epsilon: 0.5937
# Episode: 105, Total Reward: -5.699999999999998, Epsilon: 0.5908
# Episode: 106, Total Reward: -8.099999999999998, Epsilon: 0.5878
# Episode: 107, Total Reward: -6.299999999999999, Epsilon: 0.5849
# Episode: 108, Total Reward: -7.499999999999998, Epsilon: 0.5820
# Episode: 109, Total Reward: -8.099999999999998, Epsilon: 0.5790
# Episode: 110, Total Reward: -6.299999999999999, Epsilon: 0.5762
# Episode: 111, Total Reward: -6.899999999999999, Epsilon: 0.5733
# Episode: 112, Total Reward: -6.299999999999999, Epsilon: 0.5704
# Episode: 113, Total Reward: -3.899999999999998, Epsilon: 0.5676
# Episode: 114, Total Reward: -6.299999999999999, Epsilon: 0.5647
# Episode: 115, Total Reward: -5.699999999999998, Epsilon: 0.5619
# Episode: 116, Total Reward: -6.899999999999999, Epsilon: 0.5591
# Episode: 117, Total Reward: -6.899999999999999, Epsilon: 0.5563
# Episode: 118, Total Reward: -6.899999999999999, Epsilon: 0.5535
# Episode: 119, Total Reward: -6.899999999999999, Epsilon: 0.5507
# Episode: 120, Total Reward: -3.299999999999998, Epsilon: 0.5480
# Episode: 121, Total Reward: -8.099999999999998, Epsilon: 0.5452
# Episode: 122, Total Reward: -7.499999999999998, Epsilon: 0.5425
# Episode: 123, Total Reward: -5.099999999999998, Epsilon: 0.5398
# Episode: 124, Total Reward: -6.899999999999999, Epsilon: 0.5371
# Episode: 125, Total Reward: -3.899999999999998, Epsilon: 0.5344
# Episode: 126, Total Reward: -2.099999999999998, Epsilon: 0.5318
# Episode: 127, Total Reward: -6.899999999999999, Epsilon: 0.5291
# Episode: 128, Total Reward: -6.299999999999999, Epsilon: 0.5264
# Episode: 129, Total Reward: -7.499999999999998, Epsilon: 0.5238
# Episode: 130, Total Reward: -7.499999999999998, Epsilon: 0.5212
# Episode: 131, Total Reward: -6.899999999999999, Epsilon: 0.5186
# Episode: 132, Total Reward: -5.099999999999998, Epsilon: 0.5160
# Episode: 133, Total Reward: -5.699999999999998, Epsilon: 0.5134
# Episode: 134, Total Reward: -6.299999999999999, Epsilon: 0.5108
# Episode: 135, Total Reward: -5.699999999999998, Epsilon: 0.5083
# Episode: 136, Total Reward: -6.299999999999999, Epsilon: 0.5058
# Episode: 137, Total Reward: -4.499999999999998, Epsilon: 0.5032
# Episode: 138, Total Reward: -0.8999999999999986, Epsilon: 0.5007
# Episode: 139, Total Reward: -8.099999999999998, Epsilon: 0.4982
# Episode: 140, Total Reward: -0.8999999999999986, Epsilon: 0.4957
# Episode: 141, Total Reward: -0.8999999999999986, Epsilon: 0.4932
# Episode: 142, Total Reward: -6.299999999999999, Epsilon: 0.4908
# Episode: 143, Total Reward: -2.699999999999998, Epsilon: 0.4883
# Episode: 144, Total Reward: -7.499999999999998, Epsilon: 0.4859
# Episode: 145, Total Reward: -0.8999999999999986, Epsilon: 0.4834
# Episode: 146, Total Reward: -5.699999999999998, Epsilon: 0.4810
# Episode: 147, Total Reward: -5.699999999999998, Epsilon: 0.4786
# Episode: 148, Total Reward: -5.699999999999998, Epsilon: 0.4762
# Episode: 149, Total Reward: -2.099999999999998, Epsilon: 0.4738
# Episode: 150, Total Reward: -5.699999999999998, Epsilon: 0.4715
# Episode: 151, Total Reward: -6.299999999999999, Epsilon: 0.4691
# Episode: 152, Total Reward: -1.3999999999999986, Epsilon: 0.4668
# Episode: 153, Total Reward: -6.899999999999999, Epsilon: 0.4644
# Episode: 154, Total Reward: -6.299999999999999, Epsilon: 0.4621
# Episode: 155, Total Reward: -6.899999999999999, Epsilon: 0.4598
# Episode: 156, Total Reward: -7.499999999999998, Epsilon: 0.4575
# Episode: 157, Total Reward: -2.699999999999998, Epsilon: 0.4552
# Episode: 158, Total Reward: -5.099999999999998, Epsilon: 0.4529
# Episode: 159, Total Reward: -5.099999999999998, Epsilon: 0.4507
# Episode: 160, Total Reward: -4.499999999999998, Epsilon: 0.4484
# Episode: 161, Total Reward: -5.699999999999998, Epsilon: 0.4462
# Episode: 162, Total Reward: -7.499999999999998, Epsilon: 0.4440
# Episode: 163, Total Reward: -0.8999999999999986, Epsilon: 0.4417
# Episode: 164, Total Reward: -1.4999999999999982, Epsilon: 0.4395
# Episode: 165, Total Reward: -1.4999999999999982, Epsilon: 0.4373
# Episode: 166, Total Reward: 2.299999999999999, Epsilon: 0.4351
# Episode: 167, Total Reward: -2.699999999999998, Epsilon: 0.4330
# Episode: 168, Total Reward: -1.4999999999999982, Epsilon: 0.4308
# Episode: 169, Total Reward: -3.899999999999998, Epsilon: 0.4286
# Episode: 170, Total Reward: -8.099999999999998, Epsilon: 0.4265
# Episode: 171, Total Reward: -6.899999999999999, Epsilon: 0.4244
# Episode: 172, Total Reward: -7.499999999999998, Epsilon: 0.4223
# Episode: 173, Total Reward: -2.099999999999998, Epsilon: 0.4201
# Episode: 174, Total Reward: -3.899999999999998, Epsilon: 0.4180
# Episode: 175, Total Reward: -0.8999999999999986, Epsilon: 0.4159
# Episode: 176, Total Reward: -0.8999999999999986, Epsilon: 0.4139
# Episode: 177, Total Reward: -3.299999999999998, Epsilon: 0.4118
# Episode: 178, Total Reward: -5.099999999999998, Epsilon: 0.4097
# Episode: 179, Total Reward: -3.899999999999998, Epsilon: 0.4077
# Episode: 180, Total Reward: -0.8999999999999986, Epsilon: 0.4057
# Episode: 181, Total Reward: -0.8999999999999986, Epsilon: 0.4036
# Episode: 182, Total Reward: -3.899999999999998, Epsilon: 0.4016
# Episode: 183, Total Reward: -2.699999999999998, Epsilon: 0.3996
# Episode: 184, Total Reward: -5.099999999999998, Epsilon: 0.3976
# Episode: 185, Total Reward: -0.8999999999999986, Epsilon: 0.3956
# Episode: 186, Total Reward: -0.8999999999999986, Epsilon: 0.3936
# Episode: 187, Total Reward: -6.299999999999999, Epsilon: 0.3917
# Episode: 188, Total Reward: -3.899999999999998, Epsilon: 0.3897
# Episode: 189, Total Reward: -3.299999999999998, Epsilon: 0.3878
# Episode: 190, Total Reward: -1.4999999999999982, Epsilon: 0.3858
# Episode: 191, Total Reward: -5.099999999999998, Epsilon: 0.3839
# Episode: 192, Total Reward: -0.8999999999999986, Epsilon: 0.3820
# Episode: 193, Total Reward: -6.899999999999999, Epsilon: 0.3801
# Episode: 194, Total Reward: -6.299999999999999, Epsilon: 0.3782
# Episode: 195, Total Reward: -5.699999999999998, Epsilon: 0.3763
# Episode: 196, Total Reward: -3.899999999999998, Epsilon: 0.3744
# Episode: 197, Total Reward: -6.899999999999999, Epsilon: 0.3725
# Episode: 198, Total Reward: -3.299999999999998, Epsilon: 0.3707
# Episode: 199, Total Reward: -6.299999999999999, Epsilon: 0.3688
# Episode: 200, Total Reward: -0.8999999999999986, Epsilon: 0.3670
# Episode: 201, Total Reward: -7.499999999999998, Epsilon: 0.3651
# Episode: 202, Total Reward: -4.499999999999998, Epsilon: 0.3633
# Episode: 203, Total Reward: -0.8999999999999986, Epsilon: 0.3615
# Episode: 204, Total Reward: -6.299999999999999, Epsilon: 0.3597
# Episode: 205, Total Reward: -7.499999999999998, Epsilon: 0.3579
# Episode: 206, Total Reward: -0.8999999999999986, Epsilon: 0.3561
# Episode: 207, Total Reward: -2.099999999999998, Epsilon: 0.3543
# Episode: 208, Total Reward: -6.299999999999999, Epsilon: 0.3525
# Episode: 209, Total Reward: -5.099999999999998, Epsilon: 0.3508
# Episode: 210, Total Reward: -6.899999999999999, Epsilon: 0.3490
# Episode: 211, Total Reward: -7.499999999999998, Epsilon: 0.3473
# Episode: 212, Total Reward: -0.8999999999999986, Epsilon: 0.3455
# Episode: 213, Total Reward: -5.099999999999998, Epsilon: 0.3438
# Episode: 214, Total Reward: -6.299999999999999, Epsilon: 0.3421
# Episode: 215, Total Reward: -0.8999999999999986, Epsilon: 0.3404
# Episode: 216, Total Reward: -5.699999999999998, Epsilon: 0.3387
# Episode: 217, Total Reward: -0.8999999999999986, Epsilon: 0.3370
# Episode: 218, Total Reward: -3.899999999999998, Epsilon: 0.3353
# Episode: 219, Total Reward: -6.299999999999999, Epsilon: 0.3336
# Episode: 220, Total Reward: -6.899999999999999, Epsilon: 0.3320
# Episode: 221, Total Reward: -6.299999999999999, Epsilon: 0.3303
# Episode: 222, Total Reward: -8.099999999999998, Epsilon: 0.3286
# Episode: 223, Total Reward: -6.299999999999999, Epsilon: 0.3270
# Episode: 224, Total Reward: -4.499999999999998, Epsilon: 0.3254
# Episode: 225, Total Reward: -6.299999999999999, Epsilon: 0.3237
# Episode: 226, Total Reward: -0.8999999999999986, Epsilon: 0.3221
# Episode: 227, Total Reward: -0.8999999999999986, Epsilon: 0.3205
# Episode: 228, Total Reward: -4.499999999999998, Epsilon: 0.3189
# Episode: 229, Total Reward: -2.699999999999998, Epsilon: 0.3173
# Episode: 230, Total Reward: -0.8999999999999986, Epsilon: 0.3157
# Episode: 231, Total Reward: -0.8999999999999986, Epsilon: 0.3141
# Episode: 232, Total Reward: -0.8999999999999986, Epsilon: 0.3126
# Episode: 233, Total Reward: -6.299999999999999, Epsilon: 0.3110
# Episode: 234, Total Reward: -6.899999999999999, Epsilon: 0.3095
# Episode: 235, Total Reward: -0.8999999999999986, Epsilon: 0.3079
# Episode: 236, Total Reward: -5.699999999999998, Epsilon: 0.3064
# Episode: 237, Total Reward: -0.8999999999999986, Epsilon: 0.3048
# Episode: 238, Total Reward: -0.8999999999999986, Epsilon: 0.3033
# Episode: 239, Total Reward: -8.099999999999998, Epsilon: 0.3018
# Episode: 240, Total Reward: -0.8999999999999986, Epsilon: 0.3003
# Episode: 241, Total Reward: -0.09999999999999787, Epsilon: 0.2988
# Episode: 242, Total Reward: -0.8999999999999986, Epsilon: 0.2973
# Episode: 243, Total Reward: -1.4999999999999982, Epsilon: 0.2958
# Episode: 244, Total Reward: -0.8999999999999986, Epsilon: 0.2943
# Episode: 245, Total Reward: -3.899999999999998, Epsilon: 0.2929
# Episode: 246, Total Reward: -0.8999999999999986, Epsilon: 0.2914
# Episode: 247, Total Reward: -0.8999999999999986, Epsilon: 0.2899
# Episode: 248, Total Reward: -0.8999999999999986, Epsilon: 0.2885
# Episode: 249, Total Reward: -7.499999999999998, Epsilon: 0.2870
# Episode: 250, Total Reward: -1.4999999999999982, Epsilon: 0.2856
# Episode: 251, Total Reward: -0.8999999999999986, Epsilon: 0.2842
# Episode: 252, Total Reward: -5.699999999999998, Epsilon: 0.2828
# Episode: 253, Total Reward: -0.8999999999999986, Epsilon: 0.2813
# Episode: 254, Total Reward: -8.7, Epsilon: 0.2799
# Episode: 255, Total Reward: -0.8999999999999986, Epsilon: 0.2785
# Episode: 256, Total Reward: -0.8999999999999986, Epsilon: 0.2771
# Episode: 257, Total Reward: -3.299999999999998, Epsilon: 0.2758
# Episode: 258, Total Reward: -2.699999999999998, Epsilon: 0.2744
# Episode: 259, Total Reward: -0.8999999999999986, Epsilon: 0.2730
# Episode: 260, Total Reward: -5.099999999999998, Epsilon: 0.2716
# Episode: 261, Total Reward: -0.8999999999999986, Epsilon: 0.2703
# Episode: 262, Total Reward: -5.099999999999998, Epsilon: 0.2689
# Episode: 263, Total Reward: -5.099999999999998, Epsilon: 0.2676
# Episode: 264, Total Reward: -0.8999999999999986, Epsilon: 0.2663
# Episode: 265, Total Reward: -0.8999999999999986, Epsilon: 0.2649
# Episode: 266, Total Reward: -2.099999999999998, Epsilon: 0.2636
# Episode: 267, Total Reward: -2.699999999999998, Epsilon: 0.2623
# Episode: 268, Total Reward: -0.8999999999999986, Epsilon: 0.2610
# Episode: 269, Total Reward: -5.699999999999998, Epsilon: 0.2597
# Episode: 270, Total Reward: -0.8999999999999986, Epsilon: 0.2584
# Episode: 271, Total Reward: -0.8999999999999986, Epsilon: 0.2571
# Episode: 272, Total Reward: -1.4999999999999982, Epsilon: 0.2558
# Episode: 273, Total Reward: -0.8999999999999986, Epsilon: 0.2545
# Episode: 274, Total Reward: -0.8999999999999986, Epsilon: 0.2532
# Episode: 275, Total Reward: -3.899999999999998, Epsilon: 0.2520
# Episode: 276, Total Reward: -0.8999999999999986, Epsilon: 0.2507
# Episode: 277, Total Reward: -0.8999999999999986, Epsilon: 0.2495
# Episode: 278, Total Reward: -0.8999999999999986, Epsilon: 0.2482
# Episode: 279, Total Reward: -0.8999999999999986, Epsilon: 0.2470
# Episode: 280, Total Reward: -2.699999999999998, Epsilon: 0.2457
# Episode: 281, Total Reward: -0.8999999999999986, Epsilon: 0.2445
# Episode: 282, Total Reward: -7.499999999999998, Epsilon: 0.2433
# Episode: 283, Total Reward: -4.499999999999998, Epsilon: 0.2421
# Episode: 284, Total Reward: -0.8999999999999986, Epsilon: 0.2409
# Episode: 285, Total Reward: -0.8999999999999986, Epsilon: 0.2397
# Episode: 286, Total Reward: -0.29999999999999893, Epsilon: 0.2385
# Episode: 287, Total Reward: -2.699999999999998, Epsilon: 0.2373
# Episode: 288, Total Reward: -0.8999999999999986, Epsilon: 0.2361
# Episode: 289, Total Reward: -0.8999999999999986, Epsilon: 0.2349
# Episode: 290, Total Reward: -0.8999999999999986, Epsilon: 0.2337
# Episode: 291, Total Reward: -0.8999999999999986, Epsilon: 0.2326
# Episode: 292, Total Reward: -1.4999999999999982, Epsilon: 0.2314
# Episode: 293, Total Reward: 0.3000000000000016, Epsilon: 0.2302
# Episode: 294, Total Reward: -0.8999999999999986, Epsilon: 0.2291
# Episode: 295, Total Reward: -0.8999999999999986, Epsilon: 0.2279
# Episode: 296, Total Reward: -2.099999999999998, Epsilon: 0.2268
# Episode: 297, Total Reward: -0.8999999999999986, Epsilon: 0.2257
# Episode: 298, Total Reward: -5.099999999999998, Epsilon: 0.2245
# Episode: 299, Total Reward: -0.8999999999999986, Epsilon: 0.2234
# Episode: 300, Total Reward: -0.8999999999999986, Epsilon: 0.2223
# Episode: 301, Total Reward: -0.8999999999999986, Epsilon: 0.2212
# Episode: 302, Total Reward: -6.299999999999999, Epsilon: 0.2201
# Episode: 303, Total Reward: -0.8999999999999986, Epsilon: 0.2190
# Episode: 304, Total Reward: -4.499999999999998, Epsilon: 0.2179
# Episode: 305, Total Reward: -0.8999999999999986, Epsilon: 0.2168
# Episode: 306, Total Reward: 1.5, Epsilon: 0.2157
# Episode: 307, Total Reward: -0.8999999999999986, Epsilon: 0.2146
# Episode: 308, Total Reward: -0.8999999999999986, Epsilon: 0.2136
# Episode: 309, Total Reward: -0.8999999999999986, Epsilon: 0.2125
# Episode: 310, Total Reward: -0.8999999999999986, Epsilon: 0.2114
# Episode: 311, Total Reward: -0.8999999999999986, Epsilon: 0.2104
# Episode: 312, Total Reward: -0.8999999999999986, Epsilon: 0.2093
# Episode: 313, Total Reward: -0.8999999999999986, Epsilon: 0.2083
# Episode: 314, Total Reward: -0.8999999999999986, Epsilon: 0.2072
# Episode: 315, Total Reward: -2.4999999999999987, Epsilon: 0.2062
# Episode: 316, Total Reward: -0.8999999999999986, Epsilon: 0.2052
# Episode: 317, Total Reward: 0.3000000000000007, Epsilon: 0.2041
# Episode: 318, Total Reward: -3.299999999999998, Epsilon: 0.2031
# Episode: 319, Total Reward: -0.8999999999999986, Epsilon: 0.2021
# Episode: 320, Total Reward: -5.699999999999998, Epsilon: 0.2011
# Episode: 321, Total Reward: -0.8999999999999986, Epsilon: 0.2001
# Episode: 322, Total Reward: -0.8999999999999986, Epsilon: 0.1991
# Episode: 323, Total Reward: -1.5999999999999985, Epsilon: 0.1981
# Episode: 324, Total Reward: 0.3000000000000007, Epsilon: 0.1971
# Episode: 325, Total Reward: -0.8999999999999986, Epsilon: 0.1961
# Episode: 326, Total Reward: -0.8999999999999986, Epsilon: 0.1951
# Episode: 327, Total Reward: -0.8999999999999986, Epsilon: 0.1942
# Episode: 328, Total Reward: -0.8999999999999986, Epsilon: 0.1932
# Episode: 329, Total Reward: -0.8999999999999986, Epsilon: 0.1922
# Episode: 330, Total Reward: -0.8999999999999986, Epsilon: 0.1913
# Episode: 331, Total Reward: -0.29999999999999893, Epsilon: 0.1903
# Episode: 332, Total Reward: 2.799999999999999, Epsilon: 0.1893
# Episode: 333, Total Reward: -0.2999999999999985, Epsilon: 0.1884
# Episode: 334, Total Reward: -0.8999999999999986, Epsilon: 0.1875
# Episode: 335, Total Reward: 2.3999999999999986, Epsilon: 0.1865
# Episode: 336, Total Reward: -0.8999999999999986, Epsilon: 0.1856
# Episode: 337, Total Reward: -0.8999999999999986, Epsilon: 0.1847
# Episode: 338, Total Reward: -0.8999999999999986, Epsilon: 0.1837
# Episode: 339, Total Reward: 2.3999999999999986, Epsilon: 0.1828
# Episode: 340, Total Reward: 1.5, Epsilon: 0.1819
# Episode: 341, Total Reward: -0.8999999999999986, Epsilon: 0.1810
# Episode: 342, Total Reward: -0.8999999999999986, Epsilon: 0.1801
# Episode: 343, Total Reward: -0.8999999999999986, Epsilon: 0.1792
# Episode: 344, Total Reward: -0.8999999999999986, Epsilon: 0.1783
# Episode: 345, Total Reward: -0.8999999999999986, Epsilon: 0.1774
# Episode: 346, Total Reward: -0.8999999999999986, Epsilon: 0.1765
# Episode: 347, Total Reward: -0.8999999999999986, Epsilon: 0.1756
# Episode: 348, Total Reward: -0.8999999999999986, Epsilon: 0.1748
# Episode: 349, Total Reward: 2.6999999999999975, Epsilon: 0.1739
# Episode: 350, Total Reward: -0.8999999999999986, Epsilon: 0.1730
# Episode: 351, Total Reward: -0.8999999999999986, Epsilon: 0.1721
# Episode: 352, Total Reward: -0.8999999999999986, Epsilon: 0.1713
# Episode: 353, Total Reward: 1.8999999999999995, Epsilon: 0.1704
# Episode: 354, Total Reward: -0.8999999999999986, Epsilon: 0.1696
# Episode: 355, Total Reward: -1.4999999999999987, Epsilon: 0.1687
# Episode: 356, Total Reward: 1.5, Epsilon: 0.1679
# Episode: 357, Total Reward: -2.699999999999998, Epsilon: 0.1670
# Episode: 358, Total Reward: -0.8999999999999986, Epsilon: 0.1662
# Episode: 359, Total Reward: -0.8999999999999986, Epsilon: 0.1654
# Episode: 360, Total Reward: 0.3000000000000007, Epsilon: 0.1646
# Episode: 361, Total Reward: -0.8999999999999986, Epsilon: 0.1637
# Episode: 362, Total Reward: -0.8999999999999986, Epsilon: 0.1629
# Episode: 363, Total Reward: -0.8999999999999986, Epsilon: 0.1621
# Episode: 364, Total Reward: -0.8999999999999986, Epsilon: 0.1613
# Episode: 365, Total Reward: 2.9999999999999982, Epsilon: 0.1605
# Episode: 366, Total Reward: -0.39999999999999813, Epsilon: 0.1597
# Episode: 367, Total Reward: -0.8999999999999986, Epsilon: 0.1589
# Episode: 368, Total Reward: -0.8999999999999986, Epsilon: 0.1581
# Episode: 369, Total Reward: -0.8999999999999986, Epsilon: 0.1573
# Episode: 370, Total Reward: -0.19999999999999796, Epsilon: 0.1565
# Episode: 371, Total Reward: -1.1999999999999984, Epsilon: 0.1557
# Episode: 372, Total Reward: -0.8999999999999986, Epsilon: 0.1549
# Episode: 373, Total Reward: -0.8999999999999986, Epsilon: 0.1542
# Episode: 374, Total Reward: -0.8999999999999986, Epsilon: 0.1534
# Episode: 375, Total Reward: -0.8999999999999986, Epsilon: 0.1526
# Episode: 376, Total Reward: -0.8999999999999986, Epsilon: 0.1519
# Episode: 377, Total Reward: -0.8999999999999986, Epsilon: 0.1511
# Episode: 378, Total Reward: 1.5, Epsilon: 0.1504
# Episode: 379, Total Reward: -0.8999999999999986, Epsilon: 0.1496
# Episode: 380, Total Reward: -0.8999999999999986, Epsilon: 0.1489
# Episode: 381, Total Reward: -0.29999999999999893, Epsilon: 0.1481
# Episode: 382, Total Reward: -2.099999999999998, Epsilon: 0.1474
# Episode: 383, Total Reward: -0.8999999999999986, Epsilon: 0.1466
# Episode: 384, Total Reward: -0.8999999999999986, Epsilon: 0.1459
# Episode: 385, Total Reward: -0.8999999999999986, Epsilon: 0.1452
# Episode: 386, Total Reward: -0.8999999999999986, Epsilon: 0.1444
# Episode: 387, Total Reward: 0.9000000000000004, Epsilon: 0.1437
# Episode: 388, Total Reward: -0.8999999999999986, Epsilon: 0.1430
# Episode: 389, Total Reward: -0.8999999999999986, Epsilon: 0.1423
# Episode: 390, Total Reward: -0.8999999999999986, Epsilon: 0.1416
# Episode: 391, Total Reward: 0.4000000000000008, Epsilon: 0.1409
# Episode: 392, Total Reward: -0.8999999999999986, Epsilon: 0.1402
# Episode: 393, Total Reward: 0.8000000000000012, Epsilon: 0.1395
# Episode: 394, Total Reward: -0.8999999999999986, Epsilon: 0.1388
# Episode: 395, Total Reward: -0.8999999999999986, Epsilon: 0.1381
# Episode: 396, Total Reward: -0.8999999999999986, Epsilon: 0.1374
# Episode: 397, Total Reward: 2.8999999999999986, Epsilon: 0.1367
# Episode: 398, Total Reward: -0.8999999999999986, Epsilon: 0.1360
# Episode: 399, Total Reward: -0.8999999999999986, Epsilon: 0.1353
# Episode: 400, Total Reward: -0.8999999999999986, Epsilon: 0.1347
# Episode: 401, Total Reward: -0.8999999999999986, Epsilon: 0.1340
# Episode: 402, Total Reward: -0.39999999999999813, Epsilon: 0.1333
# Episode: 403, Total Reward: -0.8999999999999986, Epsilon: 0.1326
# Episode: 404, Total Reward: -0.9999999999999978, Epsilon: 0.1320
# Episode: 405, Total Reward: -0.8999999999999986, Epsilon: 0.1313
# Episode: 406, Total Reward: 0.2000000000000015, Epsilon: 0.1307
# Episode: 407, Total Reward: -0.8999999999999986, Epsilon: 0.1300
# Episode: 408, Total Reward: 1.3000000000000012, Epsilon: 0.1294
# Episode: 409, Total Reward: -0.8999999999999986, Epsilon: 0.1287
# Episode: 410, Total Reward: -3.299999999999998, Epsilon: 0.1281
# Episode: 411, Total Reward: 2.8999999999999986, Epsilon: 0.1274
# Episode: 412, Total Reward: -0.8999999999999986, Epsilon: 0.1268
# Episode: 413, Total Reward: -0.8999999999999986, Epsilon: 0.1262
# Episode: 414, Total Reward: 2.799999999999999, Epsilon: 0.1255
# Episode: 415, Total Reward: 0.4000000000000017, Epsilon: 0.1249
# Episode: 416, Total Reward: -0.8999999999999986, Epsilon: 0.1243
# Episode: 417, Total Reward: 0.3000000000000007, Epsilon: 0.1237
# Episode: 418, Total Reward: -0.8999999999999986, Epsilon: 0.1230
# Episode: 419, Total Reward: -0.8999999999999986, Epsilon: 0.1224
# Episode: 420, Total Reward: -0.8999999999999986, Epsilon: 0.1218
# Episode: 421, Total Reward: 2.1999999999999993, Epsilon: 0.1212
# Episode: 422, Total Reward: -0.8999999999999986, Epsilon: 0.1206
# Episode: 423, Total Reward: -0.8999999999999986, Epsilon: 0.1200
# Episode: 424, Total Reward: -0.8999999999999986, Epsilon: 0.1194
# Episode: 425, Total Reward: -0.5999999999999979, Epsilon: 0.1188
# Episode: 426, Total Reward: -0.8999999999999986, Epsilon: 0.1182
# Episode: 427, Total Reward: 0.9000000000000004, Epsilon: 0.1176
# Episode: 428, Total Reward: -0.2999999999999985, Epsilon: 0.1170
# Episode: 429, Total Reward: 2.3, Epsilon: 0.1164
# Episode: 430, Total Reward: 2.799999999999999, Epsilon: 0.1159
# Episode: 431, Total Reward: -0.8999999999999986, Epsilon: 0.1153
# Episode: 432, Total Reward: 2.799999999999999, Epsilon: 0.1147
# Episode: 433, Total Reward: 4.699999999999996, Epsilon: 0.1141
# Episode: 434, Total Reward: 2.299999999999999, Epsilon: 0.1136
# Episode: 435, Total Reward: -0.8999999999999986, Epsilon: 0.1130
# Episode: 436, Total Reward: 2.8999999999999986, Epsilon: 0.1124
# Episode: 437, Total Reward: -0.8999999999999986, Epsilon: 0.1119
# Episode: 438, Total Reward: 2.8999999999999986, Epsilon: 0.1113
# Episode: 439, Total Reward: -0.8999999999999986, Epsilon: 0.1107
# Episode: 440, Total Reward: 1.5, Epsilon: 0.1102
# Episode: 441, Total Reward: -0.8999999999999986, Epsilon: 0.1096
# Episode: 442, Total Reward: 2.599999999999998, Epsilon: 0.1091
# Episode: 443, Total Reward: -0.8999999999999986, Epsilon: 0.1085
# Episode: 444, Total Reward: -0.8999999999999986, Epsilon: 0.1080
# Episode: 445, Total Reward: 0.3000000000000007, Epsilon: 0.1075
# Episode: 446, Total Reward: -0.8999999999999986, Epsilon: 0.1069
# Episode: 447, Total Reward: -2.1999999999999984, Epsilon: 0.1064
# Episode: 448, Total Reward: 0.5000000000000022, Epsilon: 0.1059
# Episode: 449, Total Reward: -0.8999999999999986, Epsilon: 0.1053
# Episode: 450, Total Reward: -0.8999999999999986, Epsilon: 0.1048
# Episode: 451, Total Reward: 0.3000000000000007, Epsilon: 0.1043
# Episode: 452, Total Reward: 0.8000000000000012, Epsilon: 0.1038
# Episode: 453, Total Reward: -0.8999999999999986, Epsilon: 0.1032
# Episode: 454, Total Reward: 2.4999999999999982, Epsilon: 0.1027
# Episode: 455, Total Reward: -0.8999999999999986, Epsilon: 0.1022
# Episode: 456, Total Reward: -0.8999999999999986, Epsilon: 0.1017
# Episode: 457, Total Reward: -0.8999999999999986, Epsilon: 0.1012
# Episode: 458, Total Reward: 1.5, Epsilon: 0.1007
# Episode: 459, Total Reward: -0.8999999999999986, Epsilon: 0.1002
# Episode: 460, Total Reward: -0.8999999999999986, Epsilon: 0.0997
# Episode: 461, Total Reward: -0.8999999999999986, Epsilon: 0.0992
# Episode: 462, Total Reward: 1.5000000000000036, Epsilon: 0.0987
# Episode: 463, Total Reward: -0.8999999999999986, Epsilon: 0.0982
# Episode: 464, Total Reward: -0.8999999999999986, Epsilon: 0.0977
# Episode: 465, Total Reward: -0.8999999999999986, Epsilon: 0.0972
# Episode: 466, Total Reward: -0.8999999999999986, Epsilon: 0.0967
# Episode: 467, Total Reward: -0.8999999999999986, Epsilon: 0.0962
# Episode: 468, Total Reward: 1.5000000000000018, Epsilon: 0.0958
# Episode: 469, Total Reward: 0.5000000000000036, Epsilon: 0.0953
# Episode: 470, Total Reward: -0.8999999999999986, Epsilon: 0.0948
# Episode: 471, Total Reward: 0.3000000000000007, Epsilon: 0.0943
# Episode: 472, Total Reward: -0.8999999999999986, Epsilon: 0.0939
# Episode: 473, Total Reward: -0.8999999999999986, Epsilon: 0.0934
# Episode: 474, Total Reward: 2.8999999999999986, Epsilon: 0.0929
# Episode: 475, Total Reward: 2.3999999999999986, Epsilon: 0.0925
# Episode: 476, Total Reward: -0.8999999999999986, Epsilon: 0.0920
# Episode: 477, Total Reward: 0.9000000000000004, Epsilon: 0.0915
# Episode: 478, Total Reward: -0.8999999999999986, Epsilon: 0.0911
# Episode: 479, Total Reward: -0.8999999999999986, Epsilon: 0.0906
# Episode: 480, Total Reward: -0.8999999999999986, Epsilon: 0.0902
# Episode: 481, Total Reward: -0.8999999999999986, Epsilon: 0.0897
# Episode: 482, Total Reward: 1.9999999999999982, Epsilon: 0.0893
# Episode: 483, Total Reward: -0.8999999999999986, Epsilon: 0.0888
# Episode: 484, Total Reward: 2.299999999999999, Epsilon: 0.0884
# Episode: 485, Total Reward: -0.8999999999999986, Epsilon: 0.0879
# Episode: 486, Total Reward: 0.3000000000000007, Epsilon: 0.0875
# Episode: 487, Total Reward: -0.8999999999999986, Epsilon: 0.0871
# Episode: 488, Total Reward: 1.5, Epsilon: 0.0866
# Episode: 489, Total Reward: -0.2999999999999976, Epsilon: 0.0862
# Episode: 490, Total Reward: -0.8999999999999986, Epsilon: 0.0858
# Episode: 491, Total Reward: -0.8999999999999986, Epsilon: 0.0853
# Episode: 492, Total Reward: 2.0000000000000018, Epsilon: 0.0849
# Episode: 493, Total Reward: -0.9999999999999987, Epsilon: 0.0845
# Episode: 494, Total Reward: -0.8999999999999986, Epsilon: 0.0841
# Episode: 495, Total Reward: -1.1999999999999984, Epsilon: 0.0836
# Episode: 496, Total Reward: -0.8999999999999986, Epsilon: 0.0832
# Episode: 497, Total Reward: -0.8999999999999986, Epsilon: 0.0828
# Episode: 498, Total Reward: -0.8999999999999986, Epsilon: 0.0824
# Episode: 499, Total Reward: -0.8999999999999986, Epsilon: 0.0820
# Episode: 500, Total Reward: -0.8999999999999986, Epsilon: 0.0816
# Episode: 501, Total Reward: -0.8999999999999986, Epsilon: 0.0812
# Episode: 502, Total Reward: -0.8999999999999986, Epsilon: 0.0808
# Episode: 503, Total Reward: -0.09999999999999787, Epsilon: 0.0804
# Episode: 504, Total Reward: -0.8999999999999986, Epsilon: 0.0800
# Episode: 505, Total Reward: 2.599999999999998, Epsilon: 0.0796
# Episode: 506, Total Reward: -0.8999999999999986, Epsilon: 0.0792
# Episode: 507, Total Reward: -0.8999999999999986, Epsilon: 0.0788
# Episode: 508, Total Reward: -5.099999999999998, Epsilon: 0.0784
# Episode: 509, Total Reward: 4.100000000000001, Epsilon: 0.0780
# Episode: 510, Total Reward: -0.8999999999999986, Epsilon: 0.0776
# Episode: 511, Total Reward: 2.599999999999998, Epsilon: 0.0772
# Episode: 512, Total Reward: 0.3000000000000007, Epsilon: 0.0768
# Episode: 513, Total Reward: -0.8999999999999986, Epsilon: 0.0764
# Episode: 514, Total Reward: -0.8999999999999986, Epsilon: 0.0760
# Episode: 515, Total Reward: -0.3999999999999977, Epsilon: 0.0757
# Episode: 516, Total Reward: 2.0000000000000018, Epsilon: 0.0753
# Episode: 517, Total Reward: -0.8999999999999986, Epsilon: 0.0749
# Episode: 518, Total Reward: -0.8999999999999986, Epsilon: 0.0745
# Episode: 519, Total Reward: 2.6999999999999993, Epsilon: 0.0742
# Episode: 520, Total Reward: 1.700000000000002, Epsilon: 0.0738
# Episode: 521, Total Reward: -0.5999999999999983, Epsilon: 0.0734
# Episode: 522, Total Reward: 2.599999999999998, Epsilon: 0.0731
# Episode: 523, Total Reward: -0.8999999999999986, Epsilon: 0.0727
# Episode: 524, Total Reward: -0.8999999999999986, Epsilon: 0.0723
# Episode: 525, Total Reward: -0.8999999999999986, Epsilon: 0.0720
# Episode: 526, Total Reward: 2.3999999999999986, Epsilon: 0.0716
# Episode: 527, Total Reward: 0.2000000000000015, Epsilon: 0.0712
# Episode: 528, Total Reward: -0.8999999999999986, Epsilon: 0.0709
# Episode: 529, Total Reward: 2.0000000000000018, Epsilon: 0.0705
# Episode: 530, Total Reward: 2.0000000000000018, Epsilon: 0.0702
# Episode: 531, Total Reward: -0.9999999999999987, Epsilon: 0.0698
# Episode: 532, Total Reward: 2.6999999999999975, Epsilon: 0.0695
# Episode: 533, Total Reward: 0.7000000000000024, Epsilon: 0.0691
# Episode: 534, Total Reward: 1.6000000000000023, Epsilon: 0.0688
# Episode: 535, Total Reward: 2.6999999999999993, Epsilon: 0.0684
# Episode: 536, Total Reward: -0.8999999999999986, Epsilon: 0.0681
# Episode: 537, Total Reward: -0.8999999999999986, Epsilon: 0.0678
# Episode: 538, Total Reward: -0.8999999999999986, Epsilon: 0.0674
# Episode: 539, Total Reward: -0.8999999999999986, Epsilon: 0.0671
# Episode: 540, Total Reward: -0.8999999999999986, Epsilon: 0.0668
# Episode: 541, Total Reward: -0.8999999999999986, Epsilon: 0.0664
# Episode: 542, Total Reward: -2.2999999999999985, Epsilon: 0.0661
# Episode: 543, Total Reward: 2.1000000000000023, Epsilon: 0.0658
# Episode: 544, Total Reward: -0.3999999999999986, Epsilon: 0.0654
# Episode: 545, Total Reward: -0.8999999999999986, Epsilon: 0.0651
# Episode: 546, Total Reward: -0.19999999999999762, Epsilon: 0.0648
# Episode: 547, Total Reward: -0.8999999999999986, Epsilon: 0.0645
# Episode: 548, Total Reward: -0.8999999999999986, Epsilon: 0.0641
# Episode: 549, Total Reward: -0.8999999999999986, Epsilon: 0.0638
# Episode: 550, Total Reward: -0.8999999999999986, Epsilon: 0.0635
# Episode: 551, Total Reward: -0.8999999999999986, Epsilon: 0.0632
# Episode: 552, Total Reward: -0.8999999999999986, Epsilon: 0.0629
# Episode: 553, Total Reward: -0.8999999999999986, Epsilon: 0.0625
# Episode: 554, Total Reward: -0.8999999999999986, Epsilon: 0.0622
# Episode: 555, Total Reward: -0.8999999999999986, Epsilon: 0.0619
# Episode: 556, Total Reward: -1.5999999999999985, Epsilon: 0.0616
# Episode: 557, Total Reward: -0.8999999999999986, Epsilon: 0.0613
# Episode: 558, Total Reward: 0.10000000000000164, Epsilon: 0.0610
# Episode: 559, Total Reward: 2.0999999999999996, Epsilon: 0.0607
# Episode: 560, Total Reward: 2.100000000000002, Epsilon: 0.0604
# Episode: 561, Total Reward: -1.7999999999999987, Epsilon: 0.0601
# Episode: 562, Total Reward: 2.799999999999999, Epsilon: 0.0598
# Episode: 563, Total Reward: -0.8999999999999986, Epsilon: 0.0595
# Episode: 564, Total Reward: -0.8999999999999986, Epsilon: 0.0592
# Episode: 565, Total Reward: -0.8999999999999986, Epsilon: 0.0589
# Episode: 566, Total Reward: 0.40000000000000213, Epsilon: 0.0586
# Episode: 567, Total Reward: 2.6999999999999993, Epsilon: 0.0583
# Episode: 568, Total Reward: 2.100000000000002, Epsilon: 0.0580
# Episode: 569, Total Reward: -0.49999999999999867, Epsilon: 0.0577
# Episode: 570, Total Reward: 2.3999999999999986, Epsilon: 0.0574
# Episode: 571, Total Reward: -0.8999999999999986, Epsilon: 0.0571
# Episode: 572, Total Reward: -0.8999999999999986, Epsilon: 0.0569
# Episode: 573, Total Reward: -0.8999999999999986, Epsilon: 0.0566
# Episode: 574, Total Reward: -0.8999999999999986, Epsilon: 0.0563
# Episode: 575, Total Reward: -0.8999999999999986, Epsilon: 0.0560
# Episode: 576, Total Reward: -0.8999999999999986, Epsilon: 0.0557
# Episode: 577, Total Reward: -1.299999999999999, Epsilon: 0.0555
# Episode: 578, Total Reward: -1.0999999999999983, Epsilon: 0.0552
# Episode: 579, Total Reward: 1.8000000000000034, Epsilon: 0.0549
# Episode: 580, Total Reward: 0.10000000000000142, Epsilon: 0.0546
# Episode: 581, Total Reward: -0.8999999999999986, Epsilon: 0.0544
# Episode: 582, Total Reward: 3.099999999999998, Epsilon: 0.0541
# Episode: 583, Total Reward: -0.8999999999999986, Epsilon: 0.0538
# Episode: 584, Total Reward: -0.8999999999999986, Epsilon: 0.0535
# Episode: 585, Total Reward: 0.7000000000000024, Epsilon: 0.0533
# Episode: 586, Total Reward: -0.8999999999999986, Epsilon: 0.0530
# Episode: 587, Total Reward: -1.1999999999999986, Epsilon: 0.0527
# Episode: 588, Total Reward: 2.8999999999999986, Epsilon: 0.0525
# Episode: 589, Total Reward: -0.8999999999999986, Epsilon: 0.0522
# Episode: 590, Total Reward: 0.3999999999999986, Epsilon: 0.0520
# Episode: 591, Total Reward: -0.8999999999999986, Epsilon: 0.0517
# Episode: 592, Total Reward: -0.4999999999999978, Epsilon: 0.0514
# Episode: 593, Total Reward: -0.8999999999999986, Epsilon: 0.0512
# Episode: 594, Total Reward: 0.9000000000000004, Epsilon: 0.0509
# Episode: 595, Total Reward: 0.2000000000000015, Epsilon: 0.0507
# Episode: 596, Total Reward: 2.799999999999999, Epsilon: 0.0504
# Episode: 597, Total Reward: -0.8999999999999986, Epsilon: 0.0502
# Episode: 598, Total Reward: -0.8999999999999986, Epsilon: 0.0499
# Episode: 599, Total Reward: 1.200000000000001, Epsilon: 0.0497
# Episode: 600, Total Reward: 2.799999999999999, Epsilon: 0.0494
# Episode: 601, Total Reward: -0.8999999999999986, Epsilon: 0.0492
# Episode: 602, Total Reward: 3.0000000000000027, Epsilon: 0.0489
# Episode: 603, Total Reward: -0.8999999999999986, Epsilon: 0.0487
# Episode: 604, Total Reward: -0.09999999999999787, Epsilon: 0.0484
# Episode: 605, Total Reward: -0.8999999999999986, Epsilon: 0.0482
# Episode: 606, Total Reward: -0.5999999999999986, Epsilon: 0.0479
# Episode: 607, Total Reward: -0.8999999999999986, Epsilon: 0.0477
# Episode: 608, Total Reward: -0.8999999999999986, Epsilon: 0.0475
# Episode: 609, Total Reward: 2.6999999999999993, Epsilon: 0.0472
# Episode: 610, Total Reward: -0.29999999999999893, Epsilon: 0.0470
# Episode: 611, Total Reward: -2.2999999999999985, Epsilon: 0.0468
# Episode: 612, Total Reward: -0.8999999999999986, Epsilon: 0.0465
# Episode: 613, Total Reward: 3.099999999999998, Epsilon: 0.0463
# Episode: 614, Total Reward: -0.8999999999999986, Epsilon: 0.0461
# Episode: 615, Total Reward: -0.8999999999999986, Epsilon: 0.0458
# Episode: 616, Total Reward: -2.3999999999999977, Epsilon: 0.0456
# Episode: 617, Total Reward: -0.8999999999999986, Epsilon: 0.0454
# Episode: 618, Total Reward: -0.29999999999999893, Epsilon: 0.0452
# Episode: 619, Total Reward: 3.6999999999999975, Epsilon: 0.0449
# Episode: 620, Total Reward: 2.3999999999999986, Epsilon: 0.0447
# Episode: 621, Total Reward: -0.6999999999999977, Epsilon: 0.0445
# Episode: 622, Total Reward: -0.1999999999999993, Epsilon: 0.0443
# Episode: 623, Total Reward: -0.8999999999999986, Epsilon: 0.0440
# Episode: 624, Total Reward: 2.8999999999999986, Epsilon: 0.0438
# Episode: 625, Total Reward: -0.8999999999999986, Epsilon: 0.0436
# Episode: 626, Total Reward: -0.8999999999999986, Epsilon: 0.0434
# Episode: 627, Total Reward: -1.0999999999999965, Epsilon: 0.0432
# Episode: 628, Total Reward: -0.8999999999999986, Epsilon: 0.0429
# Episode: 629, Total Reward: -1.9999999999999987, Epsilon: 0.0427
# Episode: 630, Total Reward: -0.8999999999999986, Epsilon: 0.0425
# Episode: 631, Total Reward: 0.6000000000000014, Epsilon: 0.0423
# Episode: 632, Total Reward: 1.0999999999999996, Epsilon: 0.0421
# Episode: 633, Total Reward: 3.399999999999997, Epsilon: 0.0419
# Episode: 634, Total Reward: 1.6000000000000014, Epsilon: 0.0417
# Episode: 635, Total Reward: 2.3999999999999986, Epsilon: 0.0415
# Episode: 636, Total Reward: 0.9000000000000004, Epsilon: 0.0413
# Episode: 637, Total Reward: -0.8999999999999986, Epsilon: 0.0410
# Episode: 638, Total Reward: -0.8999999999999986, Epsilon: 0.0408
# Episode: 639, Total Reward: 2.299999999999999, Epsilon: 0.0406
# Episode: 640, Total Reward: -0.8999999999999986, Epsilon: 0.0404
# Episode: 641, Total Reward: 2.0999999999999996, Epsilon: 0.0402
# Episode: 642, Total Reward: -1.5999999999999988, Epsilon: 0.0400
# Episode: 643, Total Reward: 2.0, Epsilon: 0.0398
# Episode: 644, Total Reward: -0.8999999999999986, Epsilon: 0.0396
# Episode: 645, Total Reward: -1.2999999999999985, Epsilon: 0.0394
# Episode: 646, Total Reward: 2.599999999999998, Epsilon: 0.0392
# Episode: 647, Total Reward: 1.6000000000000014, Epsilon: 0.0390
# Episode: 648, Total Reward: -0.8999999999999986, Epsilon: 0.0388
# Episode: 649, Total Reward: 4.699999999999998, Epsilon: 0.0387
# Episode: 650, Total Reward: 0.6000000000000019, Epsilon: 0.0385
# Episode: 651, Total Reward: 2.599999999999998, Epsilon: 0.0383
# Episode: 652, Total Reward: -0.8999999999999986, Epsilon: 0.0381
# Episode: 653, Total Reward: 1.8999999999999995, Epsilon: 0.0379
# Episode: 654, Total Reward: 2.299999999999999, Epsilon: 0.0377
# Episode: 655, Total Reward: 0.40000000000000213, Epsilon: 0.0375
# Episode: 656, Total Reward: -0.8999999999999986, Epsilon: 0.0373
# Episode: 657, Total Reward: -0.8999999999999986, Epsilon: 0.0371
# Episode: 658, Total Reward: 2.599999999999998, Epsilon: 0.0369
# Episode: 659, Total Reward: 2.0999999999999996, Epsilon: 0.0368
# Episode: 660, Total Reward: 2.4000000000000004, Epsilon: 0.0366
# Episode: 661, Total Reward: 1.4000000000000026, Epsilon: 0.0364
# Episode: 662, Total Reward: 1.5, Epsilon: 0.0362
# Episode: 663, Total Reward: -0.8999999999999986, Epsilon: 0.0360
# Episode: 664, Total Reward: 2.799999999999999, Epsilon: 0.0359
# Episode: 665, Total Reward: -0.8999999999999986, Epsilon: 0.0357
# Episode: 666, Total Reward: -0.8999999999999986, Epsilon: 0.0355
# Episode: 667, Total Reward: -1.4999999999999982, Epsilon: 0.0353
# Episode: 668, Total Reward: 2.3999999999999986, Epsilon: 0.0351
# Episode: 669, Total Reward: -0.8999999999999986, Epsilon: 0.0350
# Episode: 670, Total Reward: 2.8999999999999986, Epsilon: 0.0348
# Episode: 671, Total Reward: 2.8999999999999986, Epsilon: 0.0346
# Episode: 672, Total Reward: -0.8999999999999986, Epsilon: 0.0344
# Episode: 673, Total Reward: 1.2000000000000024, Epsilon: 0.0343
# Episode: 674, Total Reward: -0.8999999999999986, Epsilon: 0.0341
# Episode: 675, Total Reward: -0.8999999999999986, Epsilon: 0.0339
# Episode: 676, Total Reward: 0.3000000000000007, Epsilon: 0.0338
# Episode: 677, Total Reward: 2.6999999999999993, Epsilon: 0.0336
# Episode: 678, Total Reward: 0.2000000000000024, Epsilon: 0.0334
# Episode: 679, Total Reward: -0.8999999999999986, Epsilon: 0.0333
# Episode: 680, Total Reward: -0.8999999999999986, Epsilon: 0.0331
# Episode: 681, Total Reward: 1.8999999999999986, Epsilon: 0.0329
# Episode: 682, Total Reward: -0.8999999999999986, Epsilon: 0.0328
# Episode: 683, Total Reward: 0.7000000000000015, Epsilon: 0.0326
# Episode: 684, Total Reward: -0.8999999999999986, Epsilon: 0.0324
# Episode: 685, Total Reward: -0.3999999999999986, Epsilon: 0.0323
# Episode: 686, Total Reward: -0.3999999999999986, Epsilon: 0.0321
# Episode: 687, Total Reward: -0.8999999999999986, Epsilon: 0.0319
# Episode: 688, Total Reward: 0.6000000000000014, Epsilon: 0.0318
# Episode: 689, Total Reward: 2.6999999999999993, Epsilon: 0.0316
# Episode: 690, Total Reward: 2.100000000000002, Epsilon: 0.0315
# Episode: 691, Total Reward: 0.6000000000000014, Epsilon: 0.0313
# Episode: 692, Total Reward: 1.1000000000000019, Epsilon: 0.0312
# Episode: 693, Total Reward: 2.1999999999999993, Epsilon: 0.0310
# Episode: 694, Total Reward: 1.3322676295501878e-15, Epsilon: 0.0308
# Episode: 695, Total Reward: 1.1000000000000014, Epsilon: 0.0307
# Episode: 696, Total Reward: -1.0999999999999988, Epsilon: 0.0305
# Episode: 697, Total Reward: -1.0999999999999985, Epsilon: 0.0304
# Episode: 698, Total Reward: -1.7999999999999985, Epsilon: 0.0302
# Episode: 699, Total Reward: -0.3999999999999986, Epsilon: 0.0301
# Episode: 700, Total Reward: 0.7000000000000015, Epsilon: 0.0299
# Episode: 701, Total Reward: -0.4999999999999982, Epsilon: 0.0298
# Episode: 702, Total Reward: 2.8999999999999977, Epsilon: 0.0296
# Episode: 703, Total Reward: 1.800000000000002, Epsilon: 0.0295
# Episode: 704, Total Reward: 1.6000000000000014, Epsilon: 0.0293
# Episode: 705, Total Reward: 2.8999999999999986, Epsilon: 0.0292
# Episode: 706, Total Reward: 0.9000000000000004, Epsilon: 0.0290
# Episode: 707, Total Reward: 2.799999999999999, Epsilon: 0.0289
# Episode: 708, Total Reward: 0.6000000000000014, Epsilon: 0.0288
# Episode: 709, Total Reward: 1.5, Epsilon: 0.0286
# Episode: 710, Total Reward: -0.8999999999999986, Epsilon: 0.0285
# Episode: 711, Total Reward: -0.8999999999999986, Epsilon: 0.0283
# Episode: 712, Total Reward: -0.8999999999999986, Epsilon: 0.0282
# Episode: 713, Total Reward: 1.4000000000000012, Epsilon: 0.0280
# Episode: 714, Total Reward: 0.6000000000000014, Epsilon: 0.0279
# Episode: 715, Total Reward: 2.6999999999999993, Epsilon: 0.0278
# Episode: 716, Total Reward: -0.8999999999999986, Epsilon: 0.0276
# Episode: 717, Total Reward: 4.299999999999994, Epsilon: 0.0275
# Episode: 718, Total Reward: 2.8999999999999986, Epsilon: 0.0274
# Episode: 719, Total Reward: -0.5999999999999979, Epsilon: 0.0272
# Episode: 720, Total Reward: 0.800000000000002, Epsilon: 0.0271
# Episode: 721, Total Reward: 0.9000000000000012, Epsilon: 0.0269
# Episode: 722, Total Reward: 2.799999999999999, Epsilon: 0.0268
# Episode: 723, Total Reward: 1.8999999999999995, Epsilon: 0.0267
# Episode: 724, Total Reward: 2.1000000000000014, Epsilon: 0.0265
# Episode: 725, Total Reward: -0.8999999999999986, Epsilon: 0.0264
# Episode: 726, Total Reward: 3.1000000000000023, Epsilon: 0.0263
# Episode: 727, Total Reward: 2.9999999999999982, Epsilon: 0.0261
# Episode: 728, Total Reward: 0.9000000000000004, Epsilon: 0.0260
# Episode: 729, Total Reward: 2.0000000000000018, Epsilon: 0.0259
# Episode: 730, Total Reward: 4.899999999999995, Epsilon: 0.0258
# Episode: 731, Total Reward: 2.0999999999999996, Epsilon: 0.0256
# Episode: 732, Total Reward: 2.8999999999999986, Epsilon: 0.0255
# Episode: 733, Total Reward: 2.9999999999999982, Epsilon: 0.0254
# Episode: 734, Total Reward: -0.8999999999999986, Epsilon: 0.0252
# Episode: 735, Total Reward: 2.6000000000000014, Epsilon: 0.0251
# Episode: 736, Total Reward: 3.099999999999998, Epsilon: 0.0250
# Episode: 737, Total Reward: 1.6000000000000014, Epsilon: 0.0249
# Episode: 738, Total Reward: 2.599999999999998, Epsilon: 0.0247
# Episode: 739, Total Reward: -0.8999999999999986, Epsilon: 0.0246
# Episode: 740, Total Reward: -0.8999999999999986, Epsilon: 0.0245
# Episode: 741, Total Reward: 1.1000000000000019, Epsilon: 0.0244
# Episode: 742, Total Reward: 1.1999999999999993, Epsilon: 0.0243
# Episode: 743, Total Reward: 0.2000000000000024, Epsilon: 0.0241
# Episode: 744, Total Reward: -0.8999999999999986, Epsilon: 0.0240
# Episode: 745, Total Reward: 1.4000000000000012, Epsilon: 0.0239
# Episode: 746, Total Reward: -0.8999999999999986, Epsilon: 0.0238
# Episode: 747, Total Reward: 0.6000000000000019, Epsilon: 0.0237
# Episode: 748, Total Reward: 2.8999999999999986, Epsilon: 0.0235
# Episode: 749, Total Reward: 3.599999999999996, Epsilon: 0.0234
# Episode: 750, Total Reward: 2.899999999999997, Epsilon: 0.0233
# Episode: 751, Total Reward: -1.0999999999999988, Epsilon: 0.0232
# ...
# Episode: 3697, Total Reward: -1.5999999999999979, Epsilon: 0.0100
# Episode: 3698, Total Reward: 5.399999999999986, Epsilon: 0.0100
# Episode: 3699, Total Reward: 2.9999999999999982, Epsilon: 0.0100
# Episode: 3700, Total Reward: -0.399999999999999, Epsilon: 0.0100
# Episode: 3701, Total Reward: 0.6000000000000019, Epsilon: 0.0100
# Episode: 3702, Total Reward: 2.299999999999999, Epsilon: 0.0100
# Episode: 3703, Total Reward: 1.3322676295501878e-15, Epsilon: 0.0100
# Episode: 3704, Total Reward: 2.0000000000000027, Epsilon: 0.0100
# Episode: 3705, Total Reward: 5.599999999999987, Epsilon: 0.0100
# Episode: 3706, Total Reward: -0.8999999999999986, Epsilon: 0.0100
# Episode: 3707, Total Reward: 2.9999999999999982, Epsilon: 0.0100
# Episode: 3708, Total Reward: -0.8999999999999986, Epsilon: 0.0100
# Episode: 3709, Total Reward: 2.100000000000003, Epsilon: 0.0100
# Episode: 3710, Total Reward: 5.299999999999988, Epsilon: 0.0100
# Episode: 3711, Total Reward: 3.6999999999999957, Epsilon: 0.0100
# Episode: 3712, Total Reward: 2.8999999999999986, Epsilon: 0.0100
# Episode: 3713, Total Reward: -2.199999999999998, Epsilon: 0.0100
# Episode: 3714, Total Reward: 1.100000000000004, Epsilon: 0.0100
# Episode: 3715, Total Reward: 2.3000000000000007, Epsilon: 0.0100
# Episode: 3716, Total Reward: -1.8999999999999986, Epsilon: 0.0100
# Episode: 3717, Total Reward: 2.0000000000000018, Epsilon: 0.0100
# Episode: 3718, Total Reward: 1.2000000000000002, Epsilon: 0.0100
# Episode: 3719, Total Reward: 2.799999999999999, Epsilon: 0.0100
# Episode: 3720, Total Reward: -2.3999999999999964, Epsilon: 0.0100
# Episode: 3721, Total Reward: 3.1999999999999975, Epsilon: 0.0100
# Episode: 3722, Total Reward: 3.7999999999999954, Epsilon: 0.0100
# Episode: 3723, Total Reward: 1.200000000000002, Epsilon: 0.0100
# Episode: 3724, Total Reward: 2.8999999999999986, Epsilon: 0.0100
# Episode: 3725, Total Reward: 4.999999999999986, Epsilon: 0.0100
# Episode: 3726, Total Reward: 4.999999999999991, Epsilon: 0.0100
# Episode: 3727, Total Reward: 9.199999999999973, Epsilon: 0.0100
# Episode: 3728, Total Reward: 2.599999999999998, Epsilon: 0.0100
# Episode: 3729, Total Reward: 2.299999999999999, Epsilon: 0.0100
# Episode: 3730, Total Reward: -1.7999999999999985, Epsilon: 0.0100
# Episode: 3731, Total Reward: 2.9999999999999982, Epsilon: 0.0100
# Episode: 3732, Total Reward: 10.899999999999975, Epsilon: 0.0100
# Episode: 3733, Total Reward: 2.9999999999999982, Epsilon: 0.0100
# Episode: 3734, Total Reward: -4.799999999999999, Epsilon: 0.0100
# Episode: 3735, Total Reward: -0.39999999999999747, Epsilon: 0.0100
# Episode: 3736, Total Reward: -1.699999999999998, Epsilon: 0.0100
# Episode: 3737, Total Reward: 15.399999999999991, Epsilon: 0.0100
# Episode: 3738, Total Reward: -1.1999999999999986, Epsilon: 0.0100
# Episode: 3739, Total Reward: 2.599999999999998, Epsilon: 0.0100
# Episode: 3740, Total Reward: -0.09999999999999787, Epsilon: 0.0100
# Episode: 3741, Total Reward: -0.8999999999999986, Epsilon: 0.0100
# Episode: 3742, Total Reward: -0.5999999999999983, Epsilon: 0.0100
# Episode: 3743, Total Reward: 2.4999999999999982, Epsilon: 0.0100
# Episode: 3744, Total Reward: 1.4000000000000021, Epsilon: 0.0100
# Episode: 3745, Total Reward: 2.220446049250313e-15, Epsilon: 0.0100
# Episode: 3746, Total Reward: 0.9000000000000008, Epsilon: 0.0100
# Episode: 3747, Total Reward: 1.4000000000000021, Epsilon: 0.0100
# Episode: 3748, Total Reward: -1.3999999999999986, Epsilon: 0.0100
# Episode: 3749, Total Reward: -1.0999999999999979, Epsilon: 0.0100
# Episode: 3750, Total Reward: 4.099999999999989, Epsilon: 0.0100
# Episode: 3751, Total Reward: -0.09999999999999787, Epsilon: 0.0100
# Episode: 3752, Total Reward: -2.2999999999999985, Epsilon: 0.0100
# Episode: 3753, Total Reward: -1.5999999999999988, Epsilon: 0.0100
# Episode: 3754, Total Reward: 3.2999999999999954, Epsilon: 0.0100
# Episode: 3755, Total Reward: 3.699999999999994, Epsilon: 0.0100
# Episode: 3756, Total Reward: 9.799999999999981, Epsilon: 0.0100
# Episode: 3757, Total Reward: 2.8999999999999986, Epsilon: 0.0100
# Episode: 3758, Total Reward: 2.8999999999999986, Epsilon: 0.0100
# Episode: 3759, Total Reward: 2.8999999999999986, Epsilon: 0.0100
# Episode: 3760, Total Reward: 1.4000000000000021, Epsilon: 0.0100
# Episode: 3761, Total Reward: 12.099999999999962, Epsilon: 0.0100
# Episode: 3762, Total Reward: 0.800000000000002, Epsilon: 0.0100
# Episode: 3763, Total Reward: 2.4999999999999982, Epsilon: 0.0100
# Episode: 3764, Total Reward: -0.09999999999999787, Epsilon: 0.0100
# Episode: 3765, Total Reward: 0.40000000000000213, Epsilon: 0.0100
# Episode: 3766, Total Reward: -1.4999999999999971, Epsilon: 0.0100
# Episode: 3767, Total Reward: 4.599999999999987, Epsilon: 0.0100
# Episode: 3768, Total Reward: -2.1999999999999984, Epsilon: 0.0100
# Episode: 3769, Total Reward: 3.099999999999998, Epsilon: 0.0100
# Episode: 3770, Total Reward: 2.9999999999999982, Epsilon: 0.0100
# Episode: 3771, Total Reward: 3.099999999999998, Epsilon: 0.0100
# Episode: 3772, Total Reward: 2.8999999999999986, Epsilon: 0.0100
# Episode: 3773, Total Reward: 3.299999999999997, Epsilon: 0.0100
# Episode: 3774, Total Reward: -0.29999999999999893, Epsilon: 0.0100
# Episode: 3775, Total Reward: 0.6999999999999984, Epsilon: 0.0100
# Episode: 3776, Total Reward: 6.299999999999979, Epsilon: 0.0100
# Episode: 3777, Total Reward: 5.399999999999986, Epsilon: 0.0100
# Episode: 3778, Total Reward: 13.799999999999958, Epsilon: 0.0100
# Episode: 3779, Total Reward: 4.899999999999996, Epsilon: 0.0100
# Episode: 3780, Total Reward: 1.799999999999991, Epsilon: 0.0100
# Episode: 3781, Total Reward: 3.1999999999999957, Epsilon: 0.0100
# Episode: 3782, Total Reward: 3.1999999999999975, Epsilon: 0.0100
# Episode: 3783, Total Reward: 2.9999999999999982, Epsilon: 0.0100
# Episode: 3784, Total Reward: 2.599999999999998, Epsilon: 0.0100
# Episode: 3785, Total Reward: 6.79999999999999, Epsilon: 0.0100
# Episode: 3786, Total Reward: 2.599999999999998, Epsilon: 0.0100
# Episode: 3787, Total Reward: 6.099999999999987, Epsilon: 0.0100
# Episode: 3788, Total Reward: -2.3999999999999986, Epsilon: 0.0100
# Episode: 3789, Total Reward: 2.9999999999999982, Epsilon: 0.0100
# Episode: 3790, Total Reward: 5.2999999999999865, Epsilon: 0.0100
# Episode: 3791, Total Reward: -0.29999999999999805, Epsilon: 0.0100
# Episode: 3792, Total Reward: -0.799999999999998, Epsilon: 0.0100
# Episode: 3793, Total Reward: 6.899999999999984, Epsilon: 0.0100
# Episode: 3794, Total Reward: 11.299999999999972, Epsilon: 0.0100
# Episode: 3795, Total Reward: 9.199999999999974, Epsilon: 0.0100
# Episode: 3796, Total Reward: 1.8999999999999968, Epsilon: 0.0100
# Episode: 3797, Total Reward: 1.300000000000002, Epsilon: 0.0100
# Episode: 3798, Total Reward: 11.599999999999962, Epsilon: 0.0100
# Episode: 3799, Total Reward: -1.6999999999999984, Epsilon: 0.0100
# Episode: 3800, Total Reward: -1.7999999999999985, Epsilon: 0.0100
# Episode: 3801, Total Reward: 4.29999999999999, Epsilon: 0.0100
# Episode: 3802, Total Reward: -1.3999999999999986, Epsilon: 0.0100
# Episode: 3803, Total Reward: -1.4999999999999982, Epsilon: 0.0100
# Episode: 3804, Total Reward: 2.9999999999999982, Epsilon: 0.0100
# Episode: 3805, Total Reward: -0.6999999999999984, Epsilon: 0.0100
# Episode: 3806, Total Reward: 13.399999999999991, Epsilon: 0.0100
# Episode: 3807, Total Reward: 7.799999999999976, Epsilon: 0.0100
# Episode: 3808, Total Reward: -1.199999999999998, Epsilon: 0.0100
# Episode: 3809, Total Reward: 1.2000000000000033, Epsilon: 0.0100
# Episode: 3810, Total Reward: 10.799999999999974, Epsilon: 0.0100
# Episode: 3811, Total Reward: -0.699999999999998, Epsilon: 0.0100
# Episode: 3812, Total Reward: 1.099999999999996, Epsilon: 0.0100
# Episode: 3813, Total Reward: -0.8999999999999986, Epsilon: 0.0100
# Episode: 3814, Total Reward: 0.700000000000002, Epsilon: 0.0100
# Episode: 3815, Total Reward: 6.199999999999985, Epsilon: 0.0100
# Episode: 3816, Total Reward: 4.099999999999998, Epsilon: 0.0100
# Episode: 3817, Total Reward: -8.099999999999998, Epsilon: 0.0100
# Episode: 3818, Total Reward: -1.5999999999999988, Epsilon: 0.0100
# Episode: 3819, Total Reward: 2.1000000000000005, Epsilon: 0.0100
# Episode: 3820, Total Reward: -1.9999999999999987, Epsilon: 0.0100
# Episode: 3821, Total Reward: 3.099999999999998, Epsilon: 0.0100
# Episode: 3822, Total Reward: -0.6999999999999991, Epsilon: 0.0100
# Episode: 3823, Total Reward: 5.699999999999978, Epsilon: 0.0100
# Episode: 3824, Total Reward: 2.9999999999999982, Epsilon: 0.0100
# Episode: 3825, Total Reward: -0.8999999999999986, Epsilon: 0.0100
# Episode: 3826, Total Reward: 11.699999999999962, Epsilon: 0.0100
# Episode: 3827, Total Reward: 2.8999999999999977, Epsilon: 0.0100
# Episode: 3828, Total Reward: 8.999999999999975, Epsilon: 0.0100
# Episode: 3829, Total Reward: 1.5000000000000004, Epsilon: 0.0100
# Episode: 3830, Total Reward: 19.000000000000014, Epsilon: 0.0100
# Episode: 3831, Total Reward: -0.6999999999999977, Epsilon: 0.0100
# Episode: 3832, Total Reward: 3.1999999999999975, Epsilon: 0.0100
# Episode: 3833, Total Reward: 3.099999999999998, Epsilon: 0.0100
# Episode: 3834, Total Reward: 19.500000000000036, Epsilon: 0.0100
# Episode: 3835, Total Reward: 2.6999999999999993, Epsilon: 0.0100
# Episode: 3836, Total Reward: -0.8999999999999986, Epsilon: 0.0100
# Episode: 3837, Total Reward: 4.79999999999999, Epsilon: 0.0100
# Episode: 3838, Total Reward: 2.9999999999999982, Epsilon: 0.0100
# Episode: 3839, Total Reward: 4.699999999999994, Epsilon: 0.0100
# Episode: 3840, Total Reward: 2.6999999999999984, Epsilon: 0.0100
# Episode: 3841, Total Reward: 3.099999999999998, Epsilon: 0.0100
# Episode: 3842, Total Reward: 1.5000000000000018, Epsilon: 0.0100
# Episode: 3843, Total Reward: 0.9000000000000021, Epsilon: 0.0100
# Episode: 3844, Total Reward: 0.30000000000000204, Epsilon: 0.0100
# Episode: 3845, Total Reward: -1.199999999999998, Epsilon: 0.0100
# Episode: 3846, Total Reward: 3.1999999999999975, Epsilon: 0.0100
# Episode: 3847, Total Reward: 5.299999999999988, Epsilon: 0.0100
# Episode: 3848, Total Reward: 3.099999999999998, Epsilon: 0.0100
# Episode: 3849, Total Reward: -1.3999999999999986, Epsilon: 0.0100
# Episode: 3850, Total Reward: 4.799999999999996, Epsilon: 0.0100
# Episode: 3851, Total Reward: 3.1999999999999975, Epsilon: 0.0100
# Episode: 3852, Total Reward: 2.3999999999999986, Epsilon: 0.0100
# Episode: 3853, Total Reward: 5.499999999999977, Epsilon: 0.0100
# Episode: 3854, Total Reward: 3.9999999999999964, Epsilon: 0.0100
# Episode: 3855, Total Reward: 3.099999999999998, Epsilon: 0.0100
# Episode: 3856, Total Reward: 4.699999999999997, Epsilon: 0.0100
# Episode: 3857, Total Reward: 5.399999999999987, Epsilon: 0.0100
# Episode: 3858, Total Reward: -0.8999999999999986, Epsilon: 0.0100
# Episode: 3859, Total Reward: 9.599999999999975, Epsilon: 0.0100
# Episode: 3860, Total Reward: 2.4999999999999893, Epsilon: 0.0100
# Episode: 3861, Total Reward: 5.099999999999987, Epsilon: 0.0100
# Episode: 3862, Total Reward: 9.799999999999974, Epsilon: 0.0100
# Episode: 3863, Total Reward: 2.599999999999998, Epsilon: 0.0100
# Episode: 3864, Total Reward: -3.699999999999998, Epsilon: 0.0100
# Episode: 3865, Total Reward: 5.7999999999999865, Epsilon: 0.0100
# Episode: 3866, Total Reward: -0.29999999999999893, Epsilon: 0.0100
# Episode: 3867, Total Reward: 0.8000000000000012, Epsilon: 0.0100
# Episode: 3868, Total Reward: 2.9999999999999982, Epsilon: 0.0100
# Episode: 3869, Total Reward: 2.9999999999999982, Epsilon: 0.0100
# Episode: 3870, Total Reward: 1.9000000000000017, Epsilon: 0.0100
# Episode: 3871, Total Reward: 0.8000000000000012, Epsilon: 0.0100
# Episode: 3872, Total Reward: 8.599999999999982, Epsilon: 0.0100
# Episode: 3873, Total Reward: 3.200000000000003, Epsilon: 0.0100
# Episode: 3874, Total Reward: 5.499999999999996, Epsilon: 0.0100
# Episode: 3875, Total Reward: 4.599999999999979, Epsilon: 0.0100
# Episode: 3876, Total Reward: 2.3999999999999986, Epsilon: 0.0100
# Episode: 3877, Total Reward: 5.899999999999986, Epsilon: 0.0100
# Episode: 3878, Total Reward: 5.599999999999985, Epsilon: 0.0100
# Episode: 3879, Total Reward: -1.0999999999999988, Epsilon: 0.0100
# Episode: 3880, Total Reward: 3.099999999999998, Epsilon: 0.0100
# Episode: 3881, Total Reward: 4.399999999999988, Epsilon: 0.0100
# Episode: 3882, Total Reward: 1.8999999999999986, Epsilon: 0.0100
# Episode: 3883, Total Reward: 13.599999999999968, Epsilon: 0.0100
# Episode: 3884, Total Reward: 2.599999999999998, Epsilon: 0.0100
# Episode: 3885, Total Reward: 2.8999999999999977, Epsilon: 0.0100
# Episode: 3886, Total Reward: 2.6999999999999993, Epsilon: 0.0100
# Episode: 3887, Total Reward: 2.4999999999999982, Epsilon: 0.0100
# Episode: 3888, Total Reward: 0.40000000000000213, Epsilon: 0.0100
# Episode: 3889, Total Reward: 2.9999999999999964, Epsilon: 0.0100
# Episode: 3890, Total Reward: 4.799999999999988, Epsilon: 0.0100
# Episode: 3891, Total Reward: 5.899999999999986, Epsilon: 0.0100
# Episode: 3892, Total Reward: 5.2999999999999865, Epsilon: 0.0100
# Episode: 3893, Total Reward: 0.7999999999999996, Epsilon: 0.0100
# Episode: 3894, Total Reward: 5.2999999999999865, Epsilon: 0.0100
# Episode: 3895, Total Reward: -0.8999999999999981, Epsilon: 0.0100
# Episode: 3896, Total Reward: 15.900000000000059, Epsilon: 0.0100
# Episode: 3897, Total Reward: 3.0999999999999988, Epsilon: 0.0100
# Episode: 3898, Total Reward: 1.7763568394002505e-15, Epsilon: 0.0100
# Episode: 3899, Total Reward: 6.999999999999984, Epsilon: 0.0100
# Episode: 3900, Total Reward: 3.1999999999999975, Epsilon: 0.0100
# Episode: 3901, Total Reward: 2.1999999999999975, Epsilon: 0.0100
# Episode: 3902, Total Reward: 2.099999999999998, Epsilon: 0.0100
# Episode: 3903, Total Reward: 10.799999999999974, Epsilon: 0.0100
# Episode: 3904, Total Reward: 4.199999999999996, Epsilon: 0.0100
# Episode: 3905, Total Reward: 2.9999999999999987, Epsilon: 0.0100
# Episode: 3906, Total Reward: 4.899999999999995, Epsilon: 0.0100
# Episode: 3907, Total Reward: 3.0999999999999988, Epsilon: 0.0100
# Episode: 3908, Total Reward: 3.599999999999996, Epsilon: 0.0100
# Episode: 3909, Total Reward: 0.30000000000000204, Epsilon: 0.0100
# Episode: 3910, Total Reward: 6.699999999999992, Epsilon: 0.0100
# Episode: 3911, Total Reward: 7.099999999999982, Epsilon: 0.0100
# Episode: 3912, Total Reward: 1.9000000000000026, Epsilon: 0.0100
# Episode: 3913, Total Reward: 0.8000000000000012, Epsilon: 0.0100
# Episode: 3914, Total Reward: -0.6999999999999977, Epsilon: 0.0100
# Episode: 3915, Total Reward: 5.499999999999988, Epsilon: 0.0100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[42], line 57
#      55 agent = DQN_plus_Agent(env, current_hyperparams)
#      56 exp_key = f"rho={rho}_kappa={kappa}"
# ---> 57 exp_res_DQN_plus[exp_key] = agent.train()
#      59 # Test the agent
#      60 test_res_DQN_plus[exp_key] = agent.test(num_episodes=5000, render=None)
#
# Cell In[36], line 127, in DQN_plus_Agent.train(self)
#     124     total_reward += reward
#     126     # Optimize model
# --> 127     self.optimize_model()
#     130 # Decay epsilon
#     131 self.epsilon = max(self.epsilon_min, self.epsilon * self.epsilon_decay)
#
# Cell In[36], line 99, in DQN_plus_Agent.optimize_model(self)
#      97 q_values = self.policy_net(states).gather(1, actions)
#      98 next_q_values = self.target_net(next_states).max(1, keepdim=True)[0]
# ---> 99 targets = rewards + (self.discount_factor * next_q_values * (1 - dones))
#     101 # Loss and backpropagation
#     102 loss = nn.MSELoss()(q_values, targets)
#
# File ~/anaconda3/envs/flappy/lib/python3.10/site-packages/torch/_tensor.py:39, in _handle_torch_function_and_wrap_type_error_to_not_implemented.<locals>.wrapped(*args, **kwargs)
#      37     if has_torch_function(args):
#      38         return handle_torch_function(wrapped, args, *args, **kwargs)
# ---> 39     return f(*args, **kwargs)
#      40 except TypeError:
#      41     return NotImplemented
#
# File ~/anaconda3/envs/flappy/lib/python3.10/site-packages/torch/_tensor.py:1028, in Tensor.__rsub__(self, other)
#    1026 @_handle_torch_function_and_wrap_type_error_to_not_implemented
#    1027 def __rsub__(self, other):
# -> 1028     return _C._VariableFunctions.rsub(self, other)
#
# KeyboardInterrupt:

# %%
test_res_DQN_plus
# Out:
# {'rho=0.2_kappa=0.75': None,
#  'rho=0.2_kappa=1.0': None,
#  'rho=0.2_kappa=1.25': None,
#  'rho=0.4_kappa=0.75': None,
#  'rho=0.4_kappa=1.0': None,
#  'rho=0.4_kappa=1.25': None,
#  'rho=0.6000000000000001_kappa=0.75': None,
#  'rho=0.6000000000000001_kappa=1.0': None,
#  'rho=0.6000000000000001_kappa=1.25': None,
#  'rho=0.8_kappa=0.75': None,
#  'rho=0.8_kappa=1.0': None,
#  'rho=0.8_kappa=1.25': None,
#  'rho=1.0_kappa=0.75': None,
#  'rho=1.0_kappa=1.0': None,
#  'rho=1.0_kappa=1.25': None}

# %%
def smooth_data(data, window_size=5):
    """Apply a simple moving average smoothing to the data."""
    return np.convolve(data, np.ones(window_size)/window_size, mode='valid')

def plot_rewards_with_opacity(rewards_dict, title, xlabel, ylabel, img_name):

    avg_rewards = {key: np.mean(rewards) for key, rewards in rewards_dict.items()} ##coefficients of variation
    top3_keys = sorted(avg_rewards, key=avg_rewards.get, reverse=True)[:3]
    
    

    fig, ax = plt.subplots(figsize=(15, 6))
    num_combinations = len(rewards_dict)
    cmap = cm.get_cmap("cool", num_combinations)
    
    # Loop through each hyperparameter combination and plot with a color from the colormap
    for idx, (key, rewards) in enumerate(rewards_dict.items()):

        smoothed_rewards = smooth_data(rewards, window_size=100)
        color = cmap(idx)  # Get the color for this hyperparameter combination
        # Adjust opacity for non-top3 combinations
        alpha = 1.0 if key in top3_keys else 0.05
        ax.plot(range(1, len(smoothed_rewards) + 1), smoothed_rewards, label=key, color=color, alpha=alpha,linewidth=0.7)
    
    # Set title with bold font
    ax.set_title(title, fontweight='bold',fontsize=18)
    ax.set_xlabel(xlabel,fontweight='bold')
    ax.set_ylabel(ylabel,fontweight='bold')
    
    
    # Place the legend in the bottom-right corner, remove title, and make it smaller
    ax.legend(loc='center left', 
              bbox_to_anchor=(1.05, 0.5),  # Position the legend box outside to the right
              borderaxespad=0., 
              fancybox=True, 
              fontsize='small', 
              markerscale=0.5, 
            )  # Make the title bold
    fig.savefig(f'img/{img_name}.png',dpi=600) 
    plt.tight_layout()  # Ensures the legend does not get clipped
    plt.show()

# Plot for exp_res (training rewards)
plot_rewards_with_opacity(exp_res_DQN_plus, "Training Rewards (Top3, Avg.)", "Episode", "Reward","TR_rewards_avg_DQN+.png")

# Plot for test_res (test rewards)
plot_rewards_with_opacity(test_res_DQN_plus, "Test Rewards (Top3, Avg.)", "Episode", "Reward","Ts_rewards_avg_DQN+.png")
# Out:
# /tmp/ipykernel_4267/1981400614.py:14: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap("cool", num_combinations)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 47
#      44 plot_rewards_with_opacity(exp_res_DQN_plus, "Training Rewards (Top3, Avg.)", "Episode", "Reward","TR_rewards_avg_DQN+.png")
#      46 # Plot for test_res (test rewards)
# ---> 47 plot_rewards_with_opacity(test_res_DQN_plus, "Test Rewards (Top3, Avg.)", "Episode", "Reward","Ts_rewards_avg_DQN+.png")
#
# Cell In[29], line 7, in plot_rewards_with_opacity(rewards_dict, title, xlabel, ylabel, img_name)
#       5 def plot_rewards_with_opacity(rewards_dict, title, xlabel, ylabel, img_name):
# ----> 7     avg_rewards = {key: np.mean(rewards) for key, rewards in rewards_dict.items()} ##coefficients of variation
#       8     top3_keys = sorted(avg_rewards, key=avg_rewards.get, reverse=True)[:3]
#      12     fig, ax = plt.subplots(figsize=(15, 6))
#
# Cell In[29], line 7, in <dictcomp>(.0)
#       5 def plot_rewards_with_opacity(rewards_dict, title, xlabel, ylabel, img_name):
# ----> 7     avg_rewards = {key: np.mean(rewards) for key, rewards in rewards_dict.items()} ##coefficients of variation
#       8     top3_keys = sorted(avg_rewards, key=avg_rewards.get, reverse=True)[:3]
#      12     fig, ax = plt.subplots(figsize=(15, 6))
#
# File ~/anaconda3/envs/flappy/lib/python3.10/site-packages/numpy/_core/fromnumeric.py:3904, in mean(a, axis, dtype, out, keepdims, where)
#    3901     else:
#    3902         return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# -> 3904 return _methods._mean(a, axis=axis, dtype=dtype,
#    3905                       out=out, **kwargs)
#
# File ~/anaconda3/envs/flappy/lib/python3.10/site-packages/numpy/_core/_methods.py:149, in _mean(a, axis, dtype, out, keepdims, where)
#     147         ret = ret.dtype.type(ret / rcount)
#     148 else:
# --> 149     ret = ret / rcount
#     151 return ret
#
# TypeError: unsupported operand type(s) for /: 'NoneType' and 'int'

# %%
def smooth_data(data, window_size=5):
    """Apply a simple moving average smoothing to the data."""
    return np.convolve(data, np.ones(window_size)/window_size, mode='valid')

def plot_rewards_with_opacity(rewards_dict, title, xlabel, ylabel, img_name):

    avg_rewards = {key: np.mean(rewards)/np.std(rewards) for key, rewards in rewards_dict.items()} 
    top3_keys = sorted(avg_rewards, key=avg_rewards.get, reverse=True)[:3]
    
    

    fig, ax = plt.subplots(figsize=(15, 6))
    num_combinations = len(rewards_dict)
    cmap = cm.get_cmap("cool", num_combinations)
    
    # Loop through each hyperparameter combination and plot with a color from the colormap
    for idx, (key, rewards) in enumerate(rewards_dict.items()):

        smoothed_rewards = smooth_data(rewards, window_size=100)
        color = cmap(idx)  # Get the color for this hyperparameter combination
        # Adjust opacity for non-top3 combinations
        alpha = 1.0 if key in top3_keys else 0.05
        ax.plot(range(1, len(smoothed_rewards) + 1), smoothed_rewards, label=key, color=color, alpha=alpha,linewidth=0.7)
    
    # Set title with bold font
    ax.set_title(title, fontweight='bold',fontsize=18)
    ax.set_xlabel(xlabel,fontweight='bold')
    ax.set_ylabel(ylabel,fontweight='bold')
    
    
    # Place the legend in the bottom-right corner, remove title, and make it smaller
    ax.legend(loc='center left', 
              bbox_to_anchor=(1.05, 0.5),  # Position the legend box outside to the right
              borderaxespad=0., 
              fancybox=True, 
              fontsize='small', 
              markerscale=0.5, 
            )  # Make the title bold
    fig.savefig(f'img/{img_name}.png',dpi=600) 
    plt.tight_layout()  # Ensures the legend does not get clipped
    plt.show()

# Plot for exp_res (training rewards)
plot_rewards_with_opacity(exp_res_DQN_plus, "Training Rewards (Top3, Avg.)", "Episode", "Reward","TR_rewards_avg_DQN+_cv.png")

# Plot for test_res (test rewards)
plot_rewards_with_opacity(test_res_DQN_plus, "Test Rewards (Top3, Avg.)", "Episode", "Reward","Ts_rewards_avg_DQN+_cv.png")
# Out:
# /tmp/ipykernel_4267/688021689.py:14: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap("cool", num_combinations)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 47
#      44 plot_rewards_with_opacity(exp_res_DQN_plus, "Training Rewards (Top3, Avg.)", "Episode", "Reward","TR_rewards_avg_DQN+_cv.png")
#      46 # Plot for test_res (test rewards)
# ---> 47 plot_rewards_with_opacity(test_res_DQN_plus, "Test Rewards (Top3, Avg.)", "Episode", "Reward","Ts_rewards_avg_DQN+_cv.png")
#
# Cell In[28], line 7, in plot_rewards_with_opacity(rewards_dict, title, xlabel, ylabel, img_name)
#       5 def plot_rewards_with_opacity(rewards_dict, title, xlabel, ylabel, img_name):
# ----> 7     avg_rewards = {key: np.mean(rewards)/np.std(rewards) for key, rewards in rewards_dict.items()}
#       8     top3_keys = sorted(avg_rewards, key=avg_rewards.get, reverse=True)[:3]
#      12     fig, ax = plt.subplots(figsize=(15, 6))
#
# Cell In[28], line 7, in <dictcomp>(.0)
#       5 def plot_rewards_with_opacity(rewards_dict, title, xlabel, ylabel, img_name):
# ----> 7     avg_rewards = {key: np.mean(rewards)/np.std(rewards) for key, rewards in rewards_dict.items()}
#       8     top3_keys = sorted(avg_rewards, key=avg_rewards.get, reverse=True)[:3]
#      12     fig, ax = plt.subplots(figsize=(15, 6))
#
# File ~/anaconda3/envs/flappy/lib/python3.10/site-packages/numpy/_core/fromnumeric.py:3904, in mean(a, axis, dtype, out, keepdims, where)
#    3901     else:
#    3902         return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# -> 3904 return _methods._mean(a, axis=axis, dtype=dtype,
#    3905                       out=out, **kwargs)
#
# File ~/anaconda3/envs/flappy/lib/python3.10/site-packages/numpy/_core/_methods.py:149, in _mean(a, axis, dtype, out, keepdims, where)
#     147         ret = ret.dtype.type(ret / rcount)
#     148 else:
# --> 149     ret = ret / rcount
#     151 return ret
#
# TypeError: unsupported operand type(s) for /: 'NoneType' and 'int'

# %%
#onemore tune#


import gymnasium
import itertools
import pickle
import gc


# Initialize environment
env = gymnasium.make("FlappyBird-v0", render_mode="rgb_array", use_lidar=True)

# Hyperparameters
hyper = {
    "learning_rate": 0.001,
    "discount_factor": 0.99,
    "epsilon": 1.0,
    "epsilon_decay": 0.995,
    "epsilon_min": 0.01,
    "batch_size": 64,
    "memory_size": 10000,
    "episodes": 80000,
    "target_update_freq": 10,
    "rho":[0.1,0.2],
    "kappa":[0.25,0.5,0.75]
}

param_combinations = itertools.product(
    hyper["rho"], 
    hyper["kappa"]
)

# Initialize result dictionaries
exp_res_DQN_plus_2 = {}
test_res_DQN_plus_2  = {}

# Iterate through parameter combinations
for rho, kappa in param_combinations:
    current_hyperparams = {
        "learning_rate": hyper["learning_rate"],
        "discount_factor": hyper["discount_factor"],
        "epsilon": hyper["epsilon"],
        "epsilon_decay": hyper["epsilon_decay"],
        "epsilon_min": hyper["epsilon_min"],
        "batch_size": hyper["batch_size"],
        "memory_size": hyper["memory_size"],
        "episodes": hyper["episodes"],
        "target_update_freq": hyper["target_update_freq"],
        "rho" :rho,
        "kappa" :kappa
    }
    
    try:
        # Train the agent
        agent = DQN_plus_Agent(env, current_hyperparams)
        exp_key = f"rho={rho}_kappa={kappa}"
        exp_res_DQN_plus_2[exp_key] = agent.train()
        
        # Test the agent
        test_res_DQN_plus_2[exp_key] = agent.test(num_episodes=5000, render=None)
        
        # Save intermediate results
        with open("exp_res_DQN_plus_2.pkl", "wb") as f:
            pickle.dump(exp_res_DQN_plus_2, f)
        with open("test_res_DQN_plus_2.pkl", "wb") as f:
            pickle.dump(test_res_DQN_plus_2, f)
        
        print(f"Finished training and testing for: {exp_key}")
    
    finally:
        # Free resources
        del agent
        gc.collect()
        env.close()


with open("exp_res_DQN_plus.pkl", "rb") as f:
    exp_res_DQN_plus = pickle.load(f)
with open("test_res_DQN_plus.pkl", "rb") as f:
    test_res_DQN_plus = pickle.load(f)

print("All parameter combinations processed.")
# Out:
# cuda
# Episode: 1, Total Reward: -8.099999999999998, Epsilon: 0.9950
# Episode: 2, Total Reward: -6.899999999999999, Epsilon: 0.9900
# Episode: 3, Total Reward: -8.099999999999998, Epsilon: 0.9851
# Episode: 4, Total Reward: -8.099999999999998, Epsilon: 0.9801
# Episode: 5, Total Reward: -7.499999999999998, Epsilon: 0.9752
# Episode: 6, Total Reward: -7.499999999999998, Epsilon: 0.9704
# Episode: 7, Total Reward: -2.699999999999998, Epsilon: 0.9655
# Episode: 8, Total Reward: -5.699999999999998, Epsilon: 0.9607
# Episode: 9, Total Reward: -6.299999999999999, Epsilon: 0.9559
# Episode: 10, Total Reward: -8.099999999999998, Epsilon: 0.9511
# Episode: 11, Total Reward: -7.499999999999998, Epsilon: 0.9464
# Episode: 12, Total Reward: -6.299999999999999, Epsilon: 0.9416
# Episode: 13, Total Reward: -6.899999999999999, Epsilon: 0.9369
# Episode: 14, Total Reward: -8.099999999999998, Epsilon: 0.9322
# Episode: 15, Total Reward: -6.299999999999999, Epsilon: 0.9276
# Episode: 16, Total Reward: -8.7, Epsilon: 0.9229
# Episode: 17, Total Reward: -8.099999999999998, Epsilon: 0.9183
# Episode: 18, Total Reward: -6.299999999999999, Epsilon: 0.9137
# Episode: 19, Total Reward: -7.499999999999998, Epsilon: 0.9092
# Episode: 20, Total Reward: -7.499999999999998, Epsilon: 0.9046
# Episode: 21, Total Reward: -7.499999999999998, Epsilon: 0.9001
# Episode: 22, Total Reward: -8.099999999999998, Epsilon: 0.8956
# Episode: 23, Total Reward: -6.899999999999999, Epsilon: 0.8911
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 54
#      52 agent = DQN_plus_Agent(env, current_hyperparams)
#      53 exp_key = f"rho={rho}_kappa={kappa}"
# ---> 54 exp_res_DQN_plus_2[exp_key] = agent.train()
#      56 # Test the agent
#      57 test_res_DQN_plus_2[exp_key] = agent.test(num_episodes=5000, render=None)
#
# Cell In[17], line 125, in DQN_plus_Agent.train(self)
#     122     total_reward += reward
#     124     # Optimize model
# --> 125     self.optimize_model()
#     128 # Decay epsilon
#     129 self.epsilon = max(self.epsilon_min, self.epsilon * self.epsilon_decay)
#
# Cell In[17], line 100, in DQN_plus_Agent.optimize_model(self)
#      97 targets = rewards + (self.discount_factor * next_q_values * (1 - dones))
#      99 # Loss and backpropagation
# --> 100 loss = nn.MSELoss()(q_values, targets)
#     101 self.optimizer.zero_grad()
#     102 loss.backward()
#
# File ~/anaconda3/envs/flappy/lib/python3.10/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/flappy/lib/python3.10/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/anaconda3/envs/flappy/lib/python3.10/site-packages/torch/nn/modules/loss.py:608, in MSELoss.forward(self, input, target)
#     607 def forward(self, input: Tensor, target: Tensor) -> Tensor:
# --> 608     return F.mse_loss(input, target, reduction=self.reduction)
#
# File ~/anaconda3/envs/flappy/lib/python3.10/site-packages/torch/nn/functional.py:3792, in mse_loss(input, target, size_average, reduce, reduction)
#    3789     reduction = _Reduction.legacy_get_string(size_average, reduce)
#    3791 expanded_input, expanded_target = torch.broadcast_tensors(input, target)
# -> 3792 return torch._C._nn.mse_loss(
#    3793     expanded_input, expanded_target, _Reduction.get_enum(reduction)
#    3794 )
#
# KeyboardInterrupt:
